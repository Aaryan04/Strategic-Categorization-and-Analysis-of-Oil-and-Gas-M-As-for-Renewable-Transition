# %%
import pandas as pd
import string
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from gensim.models import Word2Vec
from gensim.utils import simple_preprocess
from sklearn.cluster import DBSCAN
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer
import numpy as np
import nltk

# Download NLTK data files (if not already downloaded)
nltk.download('stopwords')
nltk.download('wordnet')

# Load the existing list of capabilities
capabilities_df = pd.read_excel('/Users/aaryanshah/Oncampus-Job/NLP_Gal/data/List of capabilities.xlsx')

# Concatenate Category, Segment, Sub-Segment, and Technologies/Skills into a single string
capabilities_df['combined'] = capabilities_df[['Category', 'Segment', 'Sub-Segment', 'Technologies/Skills']].agg(' '.join, axis=1)
existing_capabilities = capabilities_df['combined'].tolist()

# Load the text data
file_path = "/Users/aaryanshah/Oncampus-Job/NLP_Gal/data/TrainingSet 1.xlsx"
df = pd.read_excel(file_path, engine='openpyxl')

# Drop duplicate rows
df = df.drop_duplicates()

# Function to clean text
def clean_text(text):
    text = text.lower()
    text = ''.join([char for char in text if char not in string.punctuation])
    words = text.split()
    words = [word for word in words if word not in stopwords.words('english')]
    lemmatizer = WordNetLemmatizer()
    words = [lemmatizer.lemmatize(word) for word in words]
    return ' '.join(words)

# Apply text cleaning function
df['cleaned_text'] = df['Target Business Description'].apply(clean_text)

# Preprocess the cleaned text data into lists of words
processed_text_data = df['cleaned_text'].apply(lambda x: simple_preprocess(x)).tolist()

# Train Word2Vec model
model = Word2Vec(sentences=processed_text_data, vector_size=100, window=5, min_count=1, workers=4)
model.save("word2vec.model")  # Save the model for later use (optional)

# Preprocess the existing capabilities
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

def preprocess_capability(text):
    text = text.lower()
    text = ''.join([char for char in text if char not in string.punctuation])
    words = text.split()
    words = [word for word in words if word not in stop_words]
    words = [lemmatizer.lemmatize(word) for word in words]
    return ' '.join(words)

preprocessed_existing_capabilities = [preprocess_capability(cap) for cap in existing_capabilities]

# Find new capabilities by comparing extracted features with existing capabilities
new_capabilities = [word for word in model.wv.index_to_key if word not in preprocessed_existing_capabilities]

# Use BERT embeddings for semantic similarity
bert_model = SentenceTransformer('all-MiniLM-L6-v2')

# Embed existing capabilities and new capabilities
existing_capabilities_embeddings = bert_model.encode(preprocessed_existing_capabilities)
new_capabilities_embeddings = bert_model.encode(new_capabilities)

# Calculate cosine similarity with a higher threshold
similarity_threshold = 0.4  # Increase threshold to get more relevant capabilities
filtered_capabilities = []

for i, new_embedding in enumerate(new_capabilities_embeddings):
    similarity_scores = cosine_similarity(new_embedding.reshape(1, -1), existing_capabilities_embeddings)
    max_similarity = max(similarity_scores[0])
    if max_similarity < similarity_threshold:
        filtered_capabilities.append(new_capabilities[i])

print("Filtered Capabilities:", filtered_capabilities[:20])  # Displaying first 20 filtered capabilities for brevity

print("Length", len(filtered_capabilities))

# Get vectors for filtered capabilities
filtered_capabilities_vectors = bert_model.encode(filtered_capabilities)

# Cluster the filtered capabilities using DBSCAN
dbscan = DBSCAN(eps=0.4, min_samples=15, metric='cosine')  # Adjust eps and min_samples as needed
clusters = dbscan.fit_predict(filtered_capabilities_vectors)

# Group the words by cluster
clustered_capabilities = {}
for i, word in enumerate(filtered_capabilities):
    cluster_label = clusters[i]
    if cluster_label not in clustered_capabilities:
        clustered_capabilities[cluster_label] = []
    clustered_capabilities[cluster_label].append(word)

# Output the clusters
print("Clusters of Filtered Capabilities:")
for label, cluster_keywords in clustered_capabilities.items():
    print(f"Cluster {label}: {cluster_keywords}")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/aaryanshah/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/aaryanshah/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# /Users/aaryanshah/Library/Python/3.9/lib/python/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Filtered Capabilities: ['located', 'company', 'service', 'founded', 'manufacture', 'product', 'natural', 'ltd', 'energy', 'sa', 'business', 'engaged', 'power', 'field', 'crude', 'provide', 'station', 'co', 'asset', 'operates']
# Length 4515
# Clusters of Filtered Capabilities:
# Cluster 1: ['located', 'brazil', 'thailand', 'france', 'australia', 'spain', 'texas', 'south', 'bangkok', 'italy', 'india', 'norway', 'north', 'germany', 'argentina', 'canada', 'russian', 'uk', 'alberta', 'japan', 'indonesia', 'area', 'mexico', 'city', 'west', 'london', 'netherlands', 'san', 'africa', 'chile', 'state', 'east', 'calgary', 'china', 'austria', 'colombia', 'region', 'singapore', 'western', 'madrid', 'belgium', 'romania', 'colorado', 'america', 'california', 'thai', 'dhabi', 'portugal', 'houston', 'egypt', 'delaware', 'buenos', 'northern', 'turkey', 'asia', 'peru', 'central', 'korea', 'eastern', 'paris', 'oklahoma', 'york', 'papua', 'europe', 'la', 'tokyo', 'vietnam', 'emirate', 'rio', 'arab', 'vienna', 'kazakhstan', 'guinea', 'algeria', 'queensland', 'louisiana', 'poland', 'pakistan', 'janeiro', 'mozambique', 'pennsylvania', 'moscow', 'zealand', 'brasil', 'warsaw', 'milan', 'dutch', 'perth', 'ohio', 'massachusetts', 'sudan', 'denmark', 'southeast', 'columbia', 'country', 'osaka', 'hungary', 'bucharest', 'illinois', 'brisbane', 'nigeria', 'washington', 'arkansas', 'sydney', 'american', 'british', 'oslo', 'russia', 'venezuela', 'oman', 'lima', 'quebec', 'pasadena', 'nile', 'italia', 'namibia', 'location', 'hong', 'congo', 'barcelona', 'arabia', 'saudi', 'malaysia', 'pacific', 'province', 'morocco', 'virginia', 'mississippi', 'wyoming', 'mumbai', 'libya', 'bolivia', 'angola', 'greece', 'austin', 'tunisia', 'qatar', 'brussels', 'australian', 'siberia', 'cairo', 'espana', 'tennessee', 'iraq', 'sevilla', 'ontario', 'marseille', 'lyon', 'gabon', 'seoul', 'montreal', 'bulgaria', 'yemen', 'brasileiro', 'porto', 'ecuador', 'finland', 'rwanda', 'asian', 'hamburg', 'us', 'albania', 'minnesota', 'beijing', 'nacional', 'ukraine', 'senegal', 'hawaii', 'athens', 'amsterdam', 'place', 'switzerland', 'situated', 'azerbaijan', 'rome', 'slovenia', 'kentucky', 'taiwan', 'montana', 'alaska', 'karachi', 'strasbourg', 'gujarat', 'lithuania', 'usa', 'uganda', 'romanian', 'northeast', 'vancouver', 'luxembourg', 'indiana', 'nsw', 'berlin', 'okinawa', 'regional', 'czech', 'ireland', 'maryland', 'florence', 'bilbao', 'liverpool', 'turkmenistan', 'petersburg', 'jakarta', 'northcentral', 'michigan', 'toronto', 'khartoum', 'municipal', 'sofia', 'kenya', 'madagascar', 'wisconsin', 'hungarian', 'sweden', 'kyrgyzstan', 'panama', 'ghana', 'borneo', 'african', 'brunswick', 'adelaide', 'tanzania', 'southeastern', 'niger', 'chicago', 'near', 'kiev', 'leipzig', 'spainbased', 'austrian', 'suriname', 'pradesh', 'florida', 'munich', 'osakashi', 'indian', 'seattle', 'canadian', 'alexandria', 'portland', 'alabama', 'victoria', 'siberian', 'northwest', 'mediterranean', 'ottawa', 'iowa', 'englewood', 'budapest', 'salvador', 'az', 'nicaragua', 'guatemala', 'sacramento', 'bangladesh', 'canton', 'canadaoperated', 'auckland', 'antrim', 'cordoba', 'herzegovina', 'polish', 'inland', 'town', 'municipality', 'sudanese', 'spanish', 'thailandbased', 'croatian', 'hungarybased', 'tobago', 'trinidad', 'venice', 'pakarab', 'paso', 'rotterdam', 'european', 'bayernoil', 'slovak', 'saskatchewan', 'bosnia', 'fukuoka', 'fukuokashi', 'montpellier', 'urban', 'brunei', 'belarus', 'minsk', 'locates', 'chiba', 'frankfurt', 'tripoli', 'melbourne', 'wilmington', 'oregon', 'angeles', 'los', 'sarawak', 'midwestern', 'tonga', 'sabah', 'street', 'lille', 'aarhus', 'louisville', 'italian', 'nebraska', 'orleans', 'locatedin', 'westwind', 'ontariois', 'mississauga', 'midwest', 'westlake', 'ankara', 'mi', 'helsinki', 'ames', 'valencia', 'chiang', 'angolan', 'taipei', 'delhi', 'statesbased', 'french', 'croatia', 'zagreb', 'missouri', 'foreigner', 'cambodia', 'hokkaido', 'montenegro', 'benin', 'beninoise', 'monterey', 'nation', 'deutschland', 'madison', 'franco', 'dubai', 'leningrad', 'westhill', 'colombiana', 'turin', 'zurich', 'dublin', 'boston', 'detroit', 'selangor', 'edmonton', 'nairobi', 'kampala', 'tasmania', 'townsville', 'toledo', 'brasilia', 'westport', 'costa', 'liege', 'arizona', 'ca ...
# Cluster 0: ['company', 'manufacture', 'product', 'ltd', 'business', 'co', 'inc', 'manufacturer', 'headquartered', 'industrial', 'corp', 'produce', 'technology', 'industry', 'llc', 'construction', 'gmbh', 'building', 'subsidiary', 'producing', 'producer', 'firm', 'manufacturing', 'construct', 'developed', 'produced', 'corporation', 'made', 'factory', 'fabricated', 'build', 'structural', 'processed', 'enterprise', 'constructed', 'generates', 'supplier', 'industria', 'making', 'make', 'constructing', 'built', 'formed', 'engineered', 'composed', 'fabrication', 'structure', 'shareholder', 'companyowned', 'economic', 'industrials', 'corpfilling', 'corplubricants', 'builtin', 'corporate', 'create', 'designed', 'gmbhs', 'organization', 'marketed', 'ltds', 'industriale', 'creation', 'generated']
# Cluster -1: ['service', 'founded', 'natural', 'energy', 'sa', 'engaged', 'power', 'field', 'crude', 'provide', 'station', 'asset', 'operates', 'operate', 'also', 'provider', 'provides', 'fuel', 'electric', 'plant', 'holding', 'distribution', 'block', 'project', 'owns', 'property', 'united', 'de', 'system', 'development', 'well', 'operator', 'include', 'operation', 'utility', 'gasoline', 'insurance', 'including', 'resin', 'new', 'kingdom', 'segment', 'management', 'network', 'generation', 'liquid', 'activity', 'resource', 'pcl', 'based', 'offer', 'includes', 'sl', 'electricity', 'two', 'certain', 'equipment', 'federation', 'sale', 'develops', 'commercial', 'solution', 'portfolio', 'barrel', 'vehicle', 'spa', 'international', 'petrol', 'group', 'cement', 'terminal', 'transmission', 'prodn', 'sea', 'supply', 'software', 'license', 'philippine', 'mineral', 'three', 'plc', 'carbon', 'srl', 'sector', 'ltda', 'focus', 'paper', 'concession', 'bv', 'capacity', 'reserve', 'pty', 'use', 'used', 'shell', 'application', 'owned', 'motor', 'approximately', 'cover', 'source', 'december', 'air', 'mw', 'lp', 'focused', 'km', 'establishment', 'related', 'coating', 'mine', 'unit', 'tube', 'infrastructure', 'interest', 'day', 'paint', 'battery', 'per', 'estate', 'specialty', 'abu', 'real', 'diesel', 'alternative', 'eagle', 'owner', 'domestic', 'automotive', 'sugar', 'developing', 'aviation', 'operating', 'joint', 'operated', 'compound', 'residential', 'aire', 'adhesive', 'part', 'develop', 'sao', 'refine', 'food', 'copper', 'sell', 'october', 'brand', 'ooo', 'june', 'bp', 'petroleo', 'march', 'venture', 'organic', 'support', 'tobacco', 'port', 'pvt', 'fluid', 'data', 'rayong', 'santiago', 'export', 'process', 'filling', 'trading', 'primarily', 'petrobras', 'delivery', 'hotel', 'consulting', 'park', 'pt', 'million', 'packaging', 'thermal', 'heating', 'gold', 'convenience', 'type', 'wood', 'september', 'office', 'paulo', 'contract', 'equivalent', 'fiber', 'point', 'feed', 'public', 'using', 'undisclosed', 'information', 'consumer', 'panel', 'del', 'currently', 'communication', 'partner', 'licence', 'device', 'seam', 'car', 'component', 'high', 'four', 'nv', 'may', 'ahmedabad', 'lpg', 'one', 'main', 'division', 'fort', 'publisher', 'ptt', 'kilometer', 'cogeneration', 'good', 'cubic', 'polystyrene', 'various', 'clean', 'charging', 'middle', 'treatment', 'bar', 'capture', 'pte', 'condensate', 'animal', 'comprises', 'acquisition', 'general', 'digital', 'site', 'caspian', 'green', 'design', 'center', 'acid', 'chevron', 'miguel', 'integrated', 'synthetic', 'acreage', 'istanbul', 'inorganic', 'foot', 'total', 'comprised', 'cia', 'pulp', 'megawatt', 'sheet', 'meter', 'national', 'security', 'scatec', 'asa', 'heat', 'deep', 'land', 'gathering', 'health', 'mobil', 'light', 'established', 'shipping', 'cell', 'advanced', 'brokerage', 'round', 'installation', 'derivative', 'pvc', 'ore', 'river', 'january', 'august', 'agricultural', 'ag', 'involved', 'strait', 'direct', 'electrical', 'concrete', 'developer', 'around', 'april', 'santos', 'heavy', 'hold', 'pl', 'small', 'agency', 'like', 'solid', 'asphalt', 'recovery', 'primary', 'consisting', 'machinery', 'express', 'february', 'aircraft', 'jet', 'mandaluyong', 'exxonmobil', 'malt', 'intermediate', 'specializes', 'work', 'independent', 'repair', 'convert', 'road', 'capital', 'preparation', 'plantation', 'global', 'participacoes', 'purpose', 'right', 'research', 'range', 'additive', 'local', 'client', 'courier', 'care', 'mill', 'acre', 'agreement', 'bogota', 'stake', 'household', 'decorative', 'sharing', 'government', 'line', 'five', 'square', 'travel', 'kg', 'delta', 'da', 'chesapeake', 'acrylic', 'commodity', 'psc', 'automobile', 'special', 'percent', 'ii', 'base', 'key', 'cable', 'grease', 'payment', 'delivers', 'lease', 'throughout', 'july', 'import', 'dc', 'dioxide', 'principal', 'meat', 'electronic', 'control', 'mil', 'restaurant', 'net', 'consists', 'consist', 'others', 'pp', 'permian', 'intermediating', 're ...
# Cluster 2: ['plastic', 'steel', 'material', 'metal', 'rubber', 'aluminum', 'polyester', 'vinyl', 'fabric', 'nylon', 'alloy', 'clothing', 'woven', 'laminated', 'wooden']
# Cluster 4: ['investment', 'bank', 'financial', 'fund', 'financing', 'loan', 'income', 'banking', 'finance', 'invest', 'investor', 'invests', 'currency', 'mortgage', 'banco', 'financiera', 'cash']
# Cluster 5: ['water', 'brewery', 'beverage', 'alcohol', 'juice', 'wine', 'liquor', 'bottled', 'drink', 'beer', 'coffee', 'soda', 'tea', 'bottle', 'coke']
# Cluster 3: ['energia', 'esso', 'eni', 'energias', 'proenergia', 'enso', 'energi', 'energie', 'esco', 'andgas', 'nuelgas', 'spagas', 'ingegneria', 'enichem', 'enerkem', 'eneos', 'energas', 'enerocean', 'topco', 'enspire', 'enerco', 'enerji', 'solgas', 'enchapada', 'entre', 'en']
# Cluster 6: ['kk', 'bizkaia', 'ktpa', 'klikin', 'sebuku', 'krungthai', 'kashagan', 'kompaniia', 'klaipeda', 'minatoku', 'krasnoselkup', 'ko', 'shtokman', 'koper', 'kliks', 'fukui', 'khurja', 'kazmunaygas', 'kosmos', 'turukhansk', 'kb', 'kbhi', 'kulluk', 'krasoktzpk', 'kulker', 'kaboom', 'ruakaka', 'kazakstan', 'kimya', 'korolev', 'kolos', 'kapuas', 'koiki', 'karyatama', 'idku', 'karratha', 'kkr', 'koninklijke', 'karyoku', 'oyika', 'kotoku', 'kamchatka', 'kajhu', 'krasnoyarsk', 'khazzanmakarem', 'smbj', 'kakuna', 'kofiau', 'kompaniya', 'jabiru', 'konarka', 'korlatolt', 'kommunalkredit', 'bk', 'kultuk', 'korned', 'kboed', 'kiatnakin', 'ekologiya', 'kuang', 'ksw', 'kapolei', 'kdv', 'kkd', 'kokooha']
