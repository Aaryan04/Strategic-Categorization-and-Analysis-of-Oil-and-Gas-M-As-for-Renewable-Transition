# %%
import pandas as pd
import string
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from gensim.models import Word2Vec
from gensim.utils import simple_preprocess
from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer
import numpy as np
import nltk
from sklearn.cluster import DBSCAN

# Download NLTK data files (if not already downloaded)
nltk.download('stopwords')
nltk.download('wordnet')

# Load the existing list of capabilities
capabilities_df = pd.read_excel('/Users/aaryanshah/Oncampus-Job/NLP_Gal/data/List of capabilities.xlsx')


# Concatenate Category, Segment, Sub-Segment, and Technologies/Skills into a single string
capabilities_df['combined'] = capabilities_df[['Category', 'Segment', 'Sub-Segment', 'Technologies/Skills']].agg(' '.join, axis=1)
existing_capabilities = capabilities_df['combined'].tolist()

# Load the text data
file_path = "/Users/aaryanshah/Oncampus-Job/NLP_Gal/data/TrainingSet 1.xlsx"
df = pd.read_excel(file_path, engine='openpyxl')

# Drop duplicate rows
df = df.drop_duplicates()

# Function to clean text
def clean_text(text):
    text = text.lower()
    text = ''.join([char for char in text if char not in string.punctuation])
    words = text.split()
    words = [word for word in words if word not in stopwords.words('english')]
    lemmatizer = WordNetLemmatizer()
    words = [lemmatizer.lemmatize(word) for word in words]
    return ' '.join(words)

# Apply text cleaning function
df['cleaned_text'] = df['Target Business Description'].apply(clean_text)

# Preprocess the cleaned text data into lists of words
processed_text_data = df['cleaned_text'].apply(lambda x: simple_preprocess(x)).tolist()

# Train Word2Vec model
model = Word2Vec(sentences=processed_text_data, vector_size=100, window=5, min_count=1, workers=4)
model.save("word2vec.model")  # Save the model for later use (optional)

# Preprocess the existing capabilities
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

def preprocess_capability(text):
    text = text.lower()
    text = ''.join([char for char in text if char not in string.punctuation])
    words = text.split()
    words = [word for word in words if word not in stop_words]
    words = [lemmatizer.lemmatize(word) for word in words]
    return ' '.join(words)

preprocessed_existing_capabilities = [preprocess_capability(cap) for cap in existing_capabilities]


# Find new capabilities by comparing extracted features with existing capabilities
new_capabilities = [word for word in model.wv.index_to_key if word not in preprocessed_existing_capabilities]

# Use BERT embeddings for semantic similarity
bert_model = SentenceTransformer('all-MiniLM-L6-v2')

# Embed existing capabilities and new capabilities
existing_capabilities_embeddings = bert_model.encode(preprocessed_existing_capabilities)
new_capabilities_embeddings = bert_model.encode(new_capabilities)

# Calculate cosine similarity with a higher threshold
similarity_threshold = 0.25  # Increase threshold to get more relevant capabilities
filtered_capabilities = []

for i, new_embedding in enumerate(new_capabilities_embeddings):
    similarity_scores = cosine_similarity(new_embedding.reshape(1, -1), existing_capabilities_embeddings)
    max_similarity = max(similarity_scores[0])
    if max_similarity > similarity_threshold:
        filtered_capabilities.append(new_capabilities[i])

print("Filtered Capabilities:", filtered_capabilities[:20])  # Displaying first 20 filtered capabilities for brevity

print("Length", len(filtered_capabilities))

# Get vectors for filtered capabilities
filtered_capabilities_vectors = bert_model.encode(filtered_capabilities)

# Cluster the filtered capabilities
num_clusters = 5  # Adjust based on your needs
kmeans = KMeans(n_clusters=num_clusters, random_state=42)

kmeans.fit(filtered_capabilities_vectors)

clusters_kmeans = kmeans.predict(filtered_capabilities_vectors)


# Group the words by cluster
clustered_capabilities_kmeans = {}
for i, word in enumerate(filtered_capabilities):
    if clusters_kmeans[i] not in clustered_capabilities_kmeans:
        clustered_capabilities_kmeans[clusters_kmeans[i]] = []
    clustered_capabilities_kmeans[clusters_kmeans[i]].append(word)
    
# # Output the clusters
# print("Clusters of Filtered Capabilities using Kmeans:")
# for label, cluster_keywords in clustered_capabilities_kmeans.items():
#     print(f"Cluster {label}: {cluster_keywords}")
    
# Cluster the filtered capabilities using DBSCAN
dbscan = DBSCAN(eps=0.4, min_samples=10, metric='cosine')  # Adjust eps and min_samples as needed
clusters = dbscan.fit_predict(filtered_capabilities_vectors)

# Group the words by cluster
clustered_capabilities = {}
for i, word in enumerate(filtered_capabilities):
    cluster_label = clusters[i]
    if cluster_label not in clustered_capabilities:
        clustered_capabilities[cluster_label] = []
    clustered_capabilities[cluster_label].append(word)

# Output the clusters
print("Clusters of Filtered Capabilities:")
for label, cluster_keywords in clustered_capabilities.items():
    print(f"Cluster {label}: {cluster_keywords}")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/aaryanshah/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/aaryanshah/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# /Users/aaryanshah/Library/Python/3.9/lib/python/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Filtered Capabilities: ['gas', 'company', 'oil', 'exploration', 'production', 'service', 'manufacture', 'petroleum', 'wholesale', 'energy', 'sa', 'business', 'crude', 'station', 'operates', 'operate', 'provider', 'fuel', 'chemical', 'electric']
# Length 1147
# /Users/aaryanshah/Library/Python/3.9/lib/python/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Clusters of Filtered Capabilities:
# Cluster 0: ['gas', 'oil', 'petroleum', 'crude', 'fuel', 'gasoline', 'refinery', 'petrol', 'ethanol', 'diesel', 'shale', 'petroleo', 'propane', 'oilfield', 'hydrocarbon', 'exxon', 'methane', 'petrolera', 'gasfired', 'petrolium', 'petroli', 'petroleos', 'oilgas', 'coke', 'gasrelated', 'gasification', 'refueling', 'petrolube', 'fueling', 'gasohol', 'gasrec', 'combustion', 'petroluem']
# Cluster 1: ['company', 'production', 'manufacture', 'wholesale', 'business', 'manufacturer', 'industrial', 'corp', 'retail', 'produce', 'technology', 'industry', 'llc', 'construction', 'market', 'distributor', 'marketing', 'sale', 'supply', 'building', 'store', 'subsidiary', 'producing', 'producer', 'financial', 'manufacturing', 'trading', 'retailer', 'acquisition', 'produced', 'corporation', 'advertising', 'factory', 'warehousing', 'build', 'stock', 'supplying', 'structural', 'purchase', 'processed', 'enterprise', 'trader', 'constructed', 'generates', 'supplier', 'industria', 'making', 'make', 'constructing', 'built', 'supermarket', 'engineered', 'shop', 'selling', 'composed', 'fabrication', 'acquiring', 'ecommerce', 'industrials', 'corpfilling', 'sourcing', 'produkte', 'corplubricants', 'corporate', 'purchasing', 'shopping', 'vendor', 'acquires', 'gmbhs', 'revenue', 'merchant', 'marketed', 'commerce', 'ltds', 'industriale', 'generated', 'procurement']
# Cluster -1: ['exploration', 'service', 'energy', 'sa', 'station', 'operates', 'operate', 'provider', 'chemical', 'electric', 'plant', 'pipeline', 'distribution', 'coal', 'facility', 'development', 'operation', 'mining', 'basin', 'lubricant', 'refining', 'petrochemical', 'offshore', 'wind', 'refined', 'management', 'storage', 'water', 'network', 'liquid', 'wholesaler', 'engineering', 'electricity', 'pipe', 'renewable', 'equipment', 'federation', 'lng', 'gulf', 'barrel', 'liquefied', 'customer', 'spa', 'cement', 'transmission', 'software', 'waste', 'farm', 'mineral', 'plc', 'sector', 'concession', 'capacity', 'reserve', 'pty', 'application', 'processing', 'drilling', 'mw', 'lp', 'establishment', 'midstream', 'unit', 'tube', 'infrastructure', 'battery', 'specialty', 'turbine', 'pharmaceutical', 'developing', 'aviation', 'operating', 'downstream', 'compound', 'develop', 'refine', 'sell', 'bp', 'central', 'organic', 'port', 'pvt', 'onshore', 'fluid', 'data', 'sand', 'rayong', 'export', 'process', 'bulk', 'hotel', 'consulting', 'fertilizer', 'packaging', 'thermal', 'heating', 'convenience', 'brewery', 'maintenance', 'consumer', 'panel', 'ethylene', 'generator', 'lpg', 'division', 'fort', 'cogeneration', 'middle', 'capture', 'recycling', 'biogas', 'condensate', 'comprises', 'upstream', 'design', 'chevron', 'synthetic', 'environmental', 'inorganic', 'comprised', 'cia', 'pulp', 'megawatt', 'meter', 'security', 'asa', 'heat', 'deep', 'gathering', 'mobil', 'compressed', 'brokerage', 'pvc', 'ore', 'river', 'agricultural', 'ag', 'strait', 'electrical', 'esso', 'concrete', 'developer', 'agency', 'asphalt', 'machinery', 'express', 'aircraft', 'bitumen', 'exxonmobil', 'tank', 'intermediate', 'repair', 'benzene', 'preparation', 'plantation', 'additive', 'client', 'courier', 'mill', 'stake', 'catalyst', 'renewables', 'commodity', 'servicing', 'percent', 'base', 'grease', 'lease', 'control', 'mil', 'net', 'pp', 'permian', 'intermediating', 'repsol', 'bms', 'sp', 'distributes', 'lake', 'aromatics', 'sulphur', 'thermoplastic', 'steam', 'specializing', 'lubricating', 'olefin', 'liquified', 'platform', 'composite', 'extraction', 'monitoring', 'lube', 'biotechnology', 'textile', 'chain', 'completion', 'forest', 'pv', 'deepwater', 'managing', 'growth', 'discovery', 'disposal', 'postal', 'airline', 'devco', 'semiconductor', 'compressor', 'core', 'operational', 'hydroelectric', 'coking', 'butadiene', 'biomass', 'refineria', 'hydraulic', 'specialized', 'emission', 'deliver', 'fusion', 'cleaning', 'liquor', 'blended', 'container', 'designing', 'biodiesel', 'aggregate', 'butane', 'warehouse', 'regasification', 'distribute', 'performance', 'surface', 'partnership', 'charger', 'carrier', 'maintains', 'feedstock', 'sustainable', 'airport', 'handling', 'transshipment', 'seafood', 'reliance', 'distributing', 'geophysical', 'comprise', 'programming', 'highway', 'exchange', 'corrugated', 'bottled', 'creek', 'rail', 'maintain', 'perret', 'grid', 'bunker', 'precision', 'deposit', 'dealer', 'ornamental', 'gasket', 'enzyme', 'hydrogen', 'seismic', 'climate', 'agriculture', 'broadband', 'rosebank', 'exchanger', 'pta', 'proprietary', 'efficiency', 'sealant', 'flow', 'analytics', 'place', 'program', 'experience', 'flooring', 'provision', 'perstorp', 'reformate', 'valve', 'cleantech', 'discovered', 'liability', 'lumber', 'montana', 'stations', 'advisory', 'conversion', 'kerosene', 'corridor', 'refines', 'prospect', 'leasing', 'appalachian', 'hydros', 'farming', 'protection', 'utilization', 'generating', 'geological', 'sgps', 'leasehold', 'extruded', 'blending', 'rockies', 'tanker', 'architectural', 'hazardous', 'fork', 'thiochemicals', 'department', 'sugarcane', 'arctic', 'redwood', 'strategic', 'metrogas', 'tree', 'explore', 'alcool', 'mountain', 'solvent', 'amoco', 'energetici', 'generate', 'thermoelectric', 'retention', 'cartagena', 'galvanized', 'cylinder', 'geographic', 'bopd', 'terra', 'postmaster', 'hydrated', 'risk', 'stimulation', 'condes', 'multistage', 'timber ...
# Cluster 2: ['solar', 'photovoltaic', 'solarbased', 'solarworld', 'solarpack', 'solares', 'solarkonzept', 'sunlight', 'sunpower', 'solarbridge']
# Cluster 5: ['plastic', 'polypropylene', 'polyethylene', 'polymer', 'propylene', 'polystyrene', 'polyester', 'copolymer', 'polyvinyl', 'xylene', 'polysterene', 'polyurethane', 'polyethlyene', 'polystyrol', 'polythene', 'polyprophylene', 'polythylene', 'polybutylene', 'polyblend']
# Cluster 3: ['transportation', 'vehicle', 'transport', 'automotive', 'delivery', 'logistics', 'cargo', 'car', 'shipping', 'truck', 'travel', 'automobile', 'transit', 'passenger', 'engine', 'trucking', 'ford', 'packing', 'freight', 'parcel', 'bus', 'drive', 'truckstop', 'tow', 'destination', 'vehicular', 'traffic', 'tesla', 'hauling', 'carried', 'towing', 'railway', 'transporte', 'logistical', 'delivering']
# Cluster 4: ['sea', 'coast', 'marine', 'harbor', 'ocean', 'beach', 'submarine', 'seaport', 'maritime', 'seacom']
# Cluster 7: ['petrobras', 'petrom', 'petrocanada', 'petrohawk', 'petrocard', 'petroquimica', 'pet', 'petroquisa', 'petrocorner', 'petromanas', 'petrocat']
# Cluster 6: ['biofuel', 'biofuels', 'bioenergia', 'biocatalyst', 'biological', 'bioenergy', 'bio', 'bioethanol', 'biosev', 'regenerative', 'bioengineering', 'biopower', 'regeneration', 'biogaz', 'biotech', 'wastetoenergy', 'bioleo', 'bioforming', 'bioproducts', 'bioreactor', 'biochem', 'biosolutions']
