# %% [markdown]
# # METHOD 1

# %%
import pandas as pd
import spacy
from gensim.models import Word2Vec
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import os
# Out:
# /Users/aaryanshah/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# Load data
df_train = pd.read_excel("TrainingSet.xlsx")
df_capabilities = pd.read_excel("List of capabilities.xlsx")

# Load Spacy Model for preprocessing
nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])

# %%
def preprocess_text(doc):
    return [token.lemma_.lower() for token in doc if token.is_alpha and not token.is_stop]

# Tokenize and preprocess texts
df_train['tokens'] = df_train['Target Business Description'].apply(nlp).apply(preprocess_text)
df_capabilities['tokens'] = df_capabilities['Technologies/Skills'].astype(str).apply(nlp).apply(preprocess_text)

# %%
# Train Word2Vec model
model = Word2Vec(df_train['tokens'].tolist() + df_capabilities['tokens'].tolist(), vector_size=100, window=5, min_count=1, workers=4)

# %%
# Function to create averaged word vector for phrases
def vectorize(tokens):
    vectors = [model.wv[token] for token in tokens if token in model.wv]
    if vectors:
        return np.mean(vectors, axis=0)
    else:
        return np.zeros(model.vector_size)

# Vectorize capabilities
capability_vectors = np.array([vectorize(tokens) for tokens in df_capabilities['tokens']])

# %%
# Identify new capabilities
new_capabilities = set()
similarity_threshold = 0.5  # Adjust as necessary

for tokens in df_train['tokens']:
    for token in tokens:
        token_vec = vectorize([token])
        if token_vec.any():
            sims = cosine_similarity([token_vec], capability_vectors)
            if all(sim < similarity_threshold for sim in sims[0]):
                new_capabilities.add(token)

print("New capabilities to consider adding:", new_capabilities)
# Out:
# New capabilities to consider adding: {'saddlehorn', 'manali', 'chuo', 'isimaren', 'fig', 'denbury', 'greenagro', 'inversora', 'castor', 'bangladesh', 'tw', 'noordzeewind', 'cheshire', 'cupiagua', 'aberdeen', 'adco', 'gi', 'totalenergies', 'archaea', 'creation', 'liege', 'dow', 'nbl', 'neustadt', 'convergent', 'zap', 'vinythai', 'polyprophylene', 'isemaren', 'cryogenic', 'companhia', 'lights', 'raiznext', 'suncor', 'biobutanol', 'comillas', 'coogee', 'pitpoint', 'durango', 'ferro', 'obligation', 'energas', 'phosphate', 'eren', 'jehier', 'mahalo', 'reform', 'redivivus', 'tripoli', 'zhuhai', 'solarbridge', 'strasbourg', 'adani', 'hc', 'oyj', 'bonaparte', 'gray', 'courbevoie', 'enerkem', 'moon', 'rontec', 'aspirant', 'emulsion', 'mereenie', 'polythene', 'palmerston', 'b', 'sapa', 'woven', 'soypower', 'gunflint', 'refinement', 'iec', 'franklin', 'origin', 'limejump', 'samil', 'labo', 'pearl', 'ecooils', 'basell', 'sunseap', 'lubrilog', 'bardahl', 'dublin', 'gevo', 'frankfurt', 'engenharia', 'metallurgic', 'acure', 'regulator', 'subiaco', 'merrillville', 'synenco', 'crop', 'val', 'aarhus', 'cleam', 'santarem', 'canbriam', 'nisource', 'romans', 'toshiba', 'cascade', 'interoil', 'hmt', 'hose', 'dawei', 'photovaltic', 'renova', 'brenplast', 'jurong', 'fortaleza', 'masela', 'presently', 'chocolate', 'organize', 'mardi', 'fccl', 'rti', 'tubular', 'sadang', 'prodn', 'acetyl', 'greenbotics', 'zhejiang', 'hangzhou', 'ubiquitous', 'sulbrasileira', 'thermochemical', 'dhipaya', 'victory', 'poseidon', 'polystyrol', 'antrim', 'bay', 'temple', 'karlstein', 'tekbau', 'dynea', 'bottleneck', 'guayas', 'cotco', 'termobahia', 'simarelli', 'erm', 'delhi', 'tupman', 'comest', 'setubal', 'converter', 'ep', 'truckstop', 'petronet', 'aps', 'joslyn', 'nava', 'limay', 'sdg', 'mirai', 'vintage', 'belem', 'stroud', 'mikkel', 'energetica', 'asparuh', 'puteaux', 'companc', 'jaragua', 'texoil', 'frigorifico', 'tangguh', 'clearspans', 'insight', 'materials', 'sangu', 'belemaoil', 'lensk', 'chujin', 'infra', 'sandridge', 'activities', 'poultry', 'attiki', 'totalenergie', 'temper', 'rosebank', 'jeddah', 'risavika', 'rialti', 'khanty', 'seed', 'explorer', 'edeia', 'romax', 'irpc', 'eurelios', 'integrys', 'coventry', 'tulsa', 'oleoducto', 'coalbe', 'cairn', 'ciloger', 'bioforming', 'snam', 'hansteen', 'vanquish', 'carr', 'prod', 'brigham', 'flakeboard', 'egat', 'liquify', 'prahran', 'boulder', 'explortaion', 'shorouk', 'hysetco', 'infigen', 'techman', 'blueprint', 'tafisa', 'praetorium', 'beach', 'grenoble', 'infant', 'bunnehaven', 'whiting', 'shopping', 'accumulation', 'suministro', 'mattox', 'ryd', 'petrocat', 'peaberry', 'terpel', 'savion', 'dacma', 'manufactuer', 'oeiras', 'sonnen', 'uruguay', 'brasiliano', 'dhamma', 'formosa', 'rotterdam', 'biojet', 'mildura', 'booster', 'zema', 'pontoise', 'nesika', 'manchester', 'arizona', 'econgas', 'dunkerque', 'liqufie', 'scientific', 'calysta', 'skandia', 'twp', 'discoveries', 'culzean', 'synova', 'ossium', 'apico', 'maraba', 'transportadora', 'solarworld', 'thinxnet', 'ocensa', 'codexis', 'alkalis', 'catan', 'ampere', 'krishna', 'niobium', 'ellora', 'tow', 'tenzan', 'kosmos', 'sandnes', 'era', 'kaikas', 'quito', 'ombrea', 'hocol', 'anglo', 'samsun', 'krasgeonats', 'miwen', 'clima', 'draugen', 'andgas', 'fotech', 'bristol', 'zydeco', 'argentino', 'croatia', 'skgr', 'avon', 'shtokman', 'mandar', 'eidsvoll', 'araxa', 'hoec', 'santo', 'utejf', 'managing', 'sunrise', 'engie', 'uts', 'thorntons', 'surinam', 'dymeo', 'choay', 'rural', 'missouri', 'signage', 'dynachisso', 'westhill', 'tantalum', 'asahi', 'afab', 'helsinki', 'rosneft', 'porvoo', 'beringen', 'speciality', 'sebastian', 'nieuwegein', 'idrocarbury', 'bangalore', 'hewett', 'midia', 'tishomingo', 'budapest', 'alfa', 'jmp', 'montpellier', 'nations', 'mealhada', 'corallian', 'bucuresti', 'neptune', 'toiletry', 'angolan', 'espirito', 'impello', 'feldkirch', 'wallduern', 'cipolletti', 'cpo', 'vechicle', 'finite', 'rwxe', 'nnaisense', 'k', 'dhamra', 'elgin', 'edenvale', 'kvit ...

# %%
new_capabilities
# Out:
# {'aarhus',
#  'aasta',
#  'aberdeen',
#  'accumulation',
#  'acetyl',
#  'activities',
#  'acure',
#  'adani',
#  'adco',
#  'additives',
#  'afab',
#  'albacete',
#  'alfa',
#  'alges',
#  'alkalis',
#  'ampere',
#  'anchor',
#  'andgas',
#  'anglo',
#  'angolan',
#  'antrim',
#  'apico',
#  'aps',
#  'aqua',
#  'araxa',
#  'archaea',
#  'argentino',
#  'arizona',
#  'asahi',
#  'asparuh',
#  'aspirant',
#  'attiki',
#  'avon',
#  'b',
#  'bakery',
#  'bangalore',
#  'bangladesh',
#  'bardahl',
#  'basell',
#  'bay',
#  'beach',
#  'belem',
#  'belemaoil',
#  'bengal',
#  'beringen',
#  'biobutanol',
#  'bioforming',
#  'biojet',
#  'biorefinery',
#  'blueprint',
#  'bonaparte',
#  'bongkot',
#  'booster',
#  'bottleneck',
#  'boulder',
#  'brake',
#  'brasiliano',
#  'brenplast',
#  'brigham',
#  'bristol',
#  'bucuresti',
#  'budapest',
#  'bunnehaven',
#  'burshane',
#  'cagliari',
#  'cairn',
#  'calpam',
#  'calysta',
#  'canaport',
#  'canbriam',
#  'carr',
#  'cascade',
#  'castor',
#  'catan',
#  'cheshire',
#  'choay',
#  'chocolate',
#  'cholburi',
#  'chujin',
#  'chuo',
#  'church',
#  'ciloger',
#  'cipolletti',
#  'cleam',
#  'clearspans',
#  'clima',
#  'coalbe',
#  'codexis',
#  'comest',
#  'comillas',
#  'companc',
#  'companhia',
#  'convergent',
#  'converter',
#  'coogee',
#  'cool',
#  'copenhagen',
#  'corallian',
#  'cotco',
#  'courbevoie',
#  'cove',
#  'coventry',
#  'cpo',
#  'creation',
#  'croatia',
#  'crop',
#  'cryogenic',
#  'culzean',
#  'cupiagua',
#  'dacma',
#  'danilovsky',
#  'dawei',
#  'daystar',
#  'delhi',
#  'denbury',
#  'dhamma',
#  'dhamra',
#  'dhipaya',
#  'discoveries',
#  'dow',
#  'draugen',
#  'dublin',
#  'dunkerque',
#  'duragas',
#  'durango',
#  'dymeo',
#  'dynachisso',
#  'dynea',
#  'econgas',
#  'ecooils',
#  'ecoplastic',
#  'edeia',
#  'edenvale',
#  'egat',
#  'eidsvoll',
#  'eland',
#  'elgin',
#  'ellora',
#  'emprendimientos',
#  'emulsion',
#  'endurant',
#  'energas',
#  'energetica',
#  'enerkem',
#  'enerocean',
#  'engenharia',
#  'engie',
#  'enspire',
#  'ep',
#  'era',
#  'eren',
#  'erm',
#  'espirito',
#  'eurelios',
#  'explorer',
#  'explortaion',
#  'fccl',
#  'feldkirch',
#  'felt',
#  'ferro',
#  'fibras',
#  'fig',
#  'finite',
#  'flakeboard',
#  'forestry',
#  'formosa',
#  'fortaleza',
#  'fotech',
#  'frankfurt',
#  'franklin',
#  'frigorifico',
#  'gevo',
#  'gi',
#  'goal',
#  'gray',
#  'greenagro',
#  'greenbotics',
#  'grenoble',
#  'guayas',
#  'gubkinskiy',
#  'gunflint',
#  'habanero',
#  'han',
#  'hangzhou',
#  'hansteen',
#  'hc',
#  'hecate',
#  'helsinki',
#  'hewett',
#  'hmt',
#  'hocol',
#  'hoec',
#  'hose',
#  'hunter',
#  'hysetco',
#  'icon',
#  'idrocarbury',
#  'iec',
#  'ijmuiden',
#  'impello',
#  'infant',
#  'infigen',
#  'infra',
#  'insight',
#  'integrys',
#  'intergen',
#  'interoil',
#  'inversora',
#  'irpc',
#  'isemaren',
#  'isimaren',
#  'isophtheric',
#  'j',
#  'jaragua',
#  'jeddah',
#  'jehier',
#  'jmp',
#  'joslyn',
#  'jurong',
#  'k',
#  'kaikas',
#  'karlstein',
#  'kazakstan',
#  'khanty',
#  'kitimat',
#  'korolev',
#  'kosmos',
#  'krasgeonats',
#  'krishna',
#  'kvitebjorn',
#  'labo',
#  'lampiris',
#  'landfill',
#  'lensk',
#  'liberia',
#  'liege',
#  'lights',
#  'lille',
#  'limay',
#  'limejump',
#  'liqufie',
#  'liquify',
#  'lubrilog',
#  'madeira',
#  'mahalo',
#  'managing',
#  'manali',
#  'manchester',
#  'mandar',
#  'manufactuer',
#  'maraba',
#  'mardi',
#  'masela',
#  'masisa',
#  'materials',
#  'mattox',
#  'mealhada',
#  'mema',
#  'menlo',
#  'mereenie',
#  'merrillville',
#  'metallurgic',
#  'midia',
#  'mikkel',
#  'mildura',
#  'mirai',
#  'missouri',
#  'miwen',
#  'montpellier',
#  'moon',
#  'mwp',
#  'nations',
#  'nava',
#  'nbl',
#  'neptune',
#  'nesika',
#  'neustadt',
#  'nieuwegein',
#  'niobium',
#  'nisource',
#  'nnaisense',
#  'noordzeewind',
#  'norwegian',
#  'obligation',
#  'ocensa',
#  'oeiras',
#  'oleoducto',
#  'ombrea',
#  'orb',
#  'oregon',
#  'organize',
#  'origin',
#  'ossium',
#  'oyj',
#  'palmerston',
#  'pan',
#  'peaberry',
#  'pearl',
#  'pecten',
#  'peregrino',
#  'perez',
#  'petrocat',
#  'petronet',
#  'petronor',
#  'phosphate',
#  'photovaltic',
#  'pitpoint',
#  'plantas',
#  'polyprophylene',
#  'polystyrol',
#  'polythene',
#  'pontoise',
#  'porvoo',
#  'poseidon',
#  'poultry',
#  'praetorium',
#  'prahran',
#  'presently',
#  'prod',
#  'prodn',
#  'productsmnfr',
#  'puteaux',
#  'puzol',
#  'quito',
#  'raiznext',
#  'reactive',
#  'reading',
#  'redivivus',
#  'refinement',
#  'reform',
#  'regulator',
#  'renova',
#  'rialti',
#  'risavika',
#  'rockdale',
#  'romans',
#  'romax',
#  'rontec',
#  'rosebank',
#  'rosneft',
#  'rotterdam',
#  'rti',
#  'ruakaka',
#  'rural',
#  'rwxe',
#  'ryd',
#  'sabba',
#  'sadang',
#  'saddlehorn',
#  'salvo',
#  'samil',
#  'samsun',
#  'sandnes',
#  'sandridge',
#  'sangu',
#  'santarem',
#  'santo',
#  'sapa',
#  'savion',
#  'scientific',
#  'sdg',
#  'sebastian',
#  'seed',
#  'sentral',
#  'setubal',
#  'shenzi',
#  'shopping',
#  'shorouk',
#  'shtokman',
#  'signage',
#  'silicate',
#  'simarelli',
#  'skandia',
#  'skgr',
#  'snam',
#  'solarbridge',
#  'solarworld',
#  'solenergi',
#  'sonnen',
#  'soypower',
#  'spar',
#  'speciality',
#  'staion',
#  'stavanger',
#  'strasbourg',
#  'stroud',
#  'subiaco',
#  'sulbrasileira',
#  'suministro',
#  'suncor',
#  'sunrise',
#  'sunseap',
#  'surinam',
#  'sylvestris',
#  'synenco',
#  'synova',
#  'tacoma',
#  'tafisa',
#  'tagusgas',
#  'tampen',
#  'tangerang',
#  'tangguh',
#  'tantalum',
#  'tashelat',
#  'techman',
#  'tejeda',
#  'tekbau',
#  'temper',
#  'temple',
#  'tenzan',
#  'termobahia',
#  'terpel',
#  'texoil',
#  'thermochemical',
#  'thinxnet',
#  'thorntons',
#  'tipton',
#  'tishomingo',
#  'titan',
#  'toiletry',
#  'toreador',
#  'toshiba',
#  'totalenergie',
#  'totalenergies',
#  'tow',
#  'tramparese',
#  'transportadora',
#  'travelcenters',
#  'tripoli',
#  'truckstop',
#  'tubular',
#  'tulsa',
#  'tupman',
#  'tw',
#  'twp',
#  'ubiquitous',
#  'ursa',
#  'uruguay',
#  'utejf',
#  'uts',
#  'val',
#  'vanquish',
#  'vechicle',
#  'venice',
#  'victory',
#  'vintage',
#  'vinythai',
#  'virent',
#  'wallduern',
#  'warrendale',
#  'wattiocorp',
#  'welding',
#  'westhill',
#  'whiting',
#  'wildpoldsried',
#  'woodlands',
#  'woven',
#  'zagoryanska',
#  'zagreb',
#  'zap',
#  'zema',
#  'zhejiang',
#  'zhuhai',
#  'zydeco'}

# %% [markdown]
# # METHOD 2

# %%
import pandas as pd
import spacy
from sentence_transformers import SentenceTransformer
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# Load data
df_train = pd.read_excel("TrainingSet.xlsx")
df_capabilities = pd.read_excel("List of capabilities.xlsx")


# Load Spacy Model for advanced preprocessing
nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])

# Load a pre-trained Sentence Transformer model (BERT-based)
model = SentenceTransformer('all-MiniLM-L6-v2')

def preprocess_text(doc):
    # Add or remove custom stop words
    custom_stop_words = ['example', 'business', 'company']  # Customize this list
    return [token.lemma_.lower() for token in doc if token.is_alpha and not token.is_stop and token.text.lower() not in custom_stop_words]

# Process text data
df_train['tokens'] = df_train['Target Business Description'].apply(nlp).apply(preprocess_text)
df_capabilities['tokens'] = df_capabilities['Technologies/Skills'].astype(str).apply(nlp).apply(preprocess_text)

# Create embeddings for each set of tokens
capability_embeddings = np.array([model.encode(' '.join(tokens)) for tokens in df_capabilities['tokens'] if tokens])
train_embeddings = [model.encode(' '.join(tokens)) for tokens in df_train['tokens'] if tokens]

# Identifying new capabilities
new_capabilities = set()
similarity_threshold = 0.5  # Adjust as necessary

for idx, emb in enumerate(train_embeddings):
    sims = cosine_similarity([emb], capability_embeddings)
    if all(sim < similarity_threshold for sim in sims[0]):
        # Add all unique tokens from the description as potential capabilities
        new_capabilities.update(df_train.iloc[idx]['tokens'])

print("New capabilities to consider adding:", new_capabilities)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# /Users/aaryanshah/Library/Python/3.9/lib/python/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# New capabilities to consider adding: {'alpha', 'seismic', 'industrial', 'lac', 'portfolio', 'paso', 'metabolite', 'preparation', 'rome', 'rare', 'chain', 'thousand', 'guallarauco', 'republique', 'pallet', 'kkd', 'glue', 'hive', 'found', 'bank', 'atlas', 'danske', 'tranzen', 'drill', 'aarhus', 'cristina', 'investment', 'gerber', 'austrian', 'inorganic', 'corporation', 'dress', 'dd', 'polystyrol', 'morrovalle', 'manali', 'ldpe', 'oil', 'clichy', 'labeling', 'liability', 'scudder', 'domestic', 'tesoro', 'prncipe', 'chujin', 'lloydminster', 'szoftverfejleszto', 'sagaz', 'olaya', 'exist', 'sensing', 'moscow', 'counter', 'preservation', 'salvo', 'brooklyn', 'alabama', 'ingenieros', 'slit', 'fukui', 'cekomastik', 'kigali', 'pta', 'united', 'tube', 'polska', 'liquefied', 'sensitive', 'ornamental', 'polybutylene', 'vacuum', 'tuk', 'everyday', 'temperature', 'agroindustria', 'weather', 'government', 'physics', 'onda', 'combine', 'alta', 'special', 'ecoplac', 'way', 'zhejiang', 'pakistan', 'revenue', 'ii', 'k', 'karyatama', 'nl', 'shop', 'ituiutaba', 'guatemala', 'industriale', 'goldenalco', 'ecoslops', 'continuous', 'pao', 'food', 'sipi', 'tableros', 'rental', 'peroxide', 'adani', 'ktpa', 'aqua', 'fomm', 'decision', 'nuriootpa', 'az', 'licenses', 'terneftegaz', 'sandnes', 'machinery', 'maximum', 'stick', 'opearte', 'extent', 'mitra', 'bolzano', 'mongstad', 'raw', 'nationwide', 'fire', 'kong', 'son', 'pipeline', 'yemen', 'virent', 'petersburg', 'revolve', 'flight', 'voice', 'bahamian', 'helios', 'concentrate', 'callao', 'minas', 'salah', 'child', 'catering', 'saskatchewan', 'gudrun', 'mangalia', 'europe', 'jc', 'ink', 'postal', 'multiservizi', 'renovaveis', 'plumbing', 'ukraine', 'yx', 'arkoma', 'japan', 'painting', 'aromatic', 'freepoint', 'arakan', 'seaport', 'oeiras', 'cosmetic', 'mediterranean', 'franchise', 'propulsion', 'blue', 'isopropyl', 'ctgs', 'temple', 'epoxy', 'consulting', 'zao', 'livre', 'hc', 'contactor', 'worldwide', 'russneft', 'schweiger', 'mobile', 'geographic', 'tank', 'aberdeen', 'responsibility', 'chemical', 'mortar', 'leasing', 'kaybob', 'tillieres', 'building', 'nylon', 'greenfield', 'reading', 'williams', 'mass', 'material', 'sudanese', 'pulse', 'poplar', 'tyumen', 'jabiru', 'asia', 'conditioning', 'zentrale', 'ship', 'standard', 'biological', 'tom', 'associate', 'paint', 'mount', 'dynachisso', 'corp', 'prevention', 'bc', 'coventry', 'own', 'panama', 'bioengineering', 'botanical', 'additive', 'add', 'remote', 'petrol', 'sweetener', 'pachage', 'curitiba', 'pan', 'offer', 'remain', 'agri', 'transit', 'mirai', 'krishna', 'hour', 'canaport', 'future', 'hybond', 'simulation', 'mines', 'mobil', 'silico', 'duty', 'irwindale', 'nieuwegein', 'visa', 'kk', 'investicijos', 'et', 'stainless', 'spectrum', 'producer', 'belgium', 'australia', 'portugal', 'event', 'plant', 'trademark', 'pt', 'szolgaltato', 'melamine', 'palmerston', 'zurich', 'concepcion', 'great', 'copenhagen', 'financing', 'bio', 'transplant', 'disposable', 'oyika', 'east', 'roman', 'improve', 'municipality', 'establish', 'biofuel', 'urban', 'adco', 'stroud', 'transshipment', 'piterstroy', 'zero', 'hudgins', 'stekene', 'barcelona', 'relate', 'beverage', 'flex', 'dutch', 'kitimat', 'xage', 'canbriam', 'tecnicontrol', 'villaverde', 'printing', 'cruz', 'maryland', 'madison', 'brandizzo', 'slaughtering', 'laredo', 'detergent', 'finch', 'integrators', 'london', 'colombia', 'spindle', 'publisher', 'grupo', 'hipotecarios', 'demand', 'connectivity', 'federal', 'statfjord', 'increase', 'agricola', 'billings', 'infra', 'victory', 'weight', 'industrialisation', 'podium', 'pbf', 'liquefaction', 'mail', 'almagro', 'arctic', 'stream', 'wash', 'integral', 'help', 'pcl', 'buren', 'acetyl', 'provox', 'berau', 'inpex', 'topco', 'neustadt', 'blended', 'stop', 'iber', 'shape', 'actividades', 'wx', 'mc', 'villacoublay', 'angeles', 'loan', 'glove', 'packet', 'solid', 'teas', 'flat', 'maroc', 'welding', 'leverage', 'limestone', 'location', 'black', 'structural', 'growth', 'ac', 'bak ...

# %% [markdown]
# # METHOD 3

# %%
import pandas as pd
import spacy
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer
import numpy as np

# Load data
df_train = pd.read_excel("TrainingSet.xlsx")
df_capabilities = pd.read_excel("List of capabilities.xlsx")

# Load Spacy Model with NER
nlp = spacy.load('en_core_web_sm')

# Load a pre-trained Sentence Transformer model (BERT-based)
model = SentenceTransformer('all-MiniLM-L6-v2')

def extract_phrases(text):
    doc = nlp(text)
    # Extract N-grams and named entities
    phrases = set([token.lemma_.lower() for token in doc if not token.is_stop and token.is_alpha])
    phrases.update([" ".join(token.lemma_.lower() for token in entity) for entity in doc.ents])  # Named entities
    n_grams = [doc[i:i+3].text.lower() for i in range(len(doc)-2)]  # Trigrams
    n_grams.extend([doc[i:i+2].text.lower() for i in range(len(doc)-1)])  # Bigrams
    phrases.update(n_grams)
    return list(phrases)

# Apply phrase extraction
df_train['phrases'] = df_train['Target Business Description'].apply(extract_phrases)
df_capabilities['phrases'] = df_capabilities['Technologies/Skills'].astype(str).apply(extract_phrases)

# Flatten and vectorize the capabilities
flat_capabilities = [item for sublist in df_capabilities['phrases'] for item in sublist]
capability_embeddings = np.array([model.encode(phrase) for phrase in flat_capabilities if phrase.strip()])

# Identify new capabilities
new_capabilities = set()
similarity_threshold = 0.1  # Adjust based on your results

for phrases in df_train['phrases']:
    for phrase in phrases:
        if phrase.strip():
            phrase_emb = model.encode(phrase)
            sims = cosine_similarity([phrase_emb], capability_embeddings)
            if all(sim < similarity_threshold for sim in sims[0]):
                new_capabilities.add(phrase)

print("New capabilities to consider adding:", new_capabilities)
# Out:
# /Users/aaryanshah/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/aaryanshah/Library/Python/3.9/lib/python/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# /Users/aaryanshah/Library/Python/3.9/lib/python/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# New capabilities to consider adding: {'dakota. the', 'global portfolio', 'mfc', 'brasilia and', 'dakota within', 'principal creditos hipotecarios', 'in kitimat', 'roncador field of', 'august 2011', 'and peroxides', 'gaz', 'in angola', 'pallonji infrastructure capital', '220,000 barrel', 'americas inc', '(wilga park', 'in athens,', 'resinas sl is', 'enerji sanayi ve', 'located in bogota', 'fibers brand names', 'and two breweries', ', home', 'led sl is', 'omv ag', 'caarapo ltda', 'hindustan', 'portugal, provides', 'company produces acrylonitrile', 'to 1,200 mm', 'blocks included block', 'located in ijmuiden', 'in saskatchewan', 'by equinor', 'in libya', 'renouvelables sarl is', 'bv will', 'venture between mitsubishi', 'asia) pcl', 'valdesolar hive sl', 'in palo', 'portfolio includes such', ', 1954', 'of equinor brasil', 'pune,', 'gerber products', 'founded on march', 'brasiliano distribuidora sa', 'michigan, us', 'located in accra', 'pcl, located', 'bac thor', 'publisher. it', '15th convention', 'shi tokyo,', 'fpso mystras producao', '5a was', 'in boulder,', 'can be used', 'and wholesale iron', 'includes 50%', 'in norway,', 'attiki', 'msts', 'located in uganda', 'and abrasive', 'by pt bahari', 'located in warsaw', 'royal dutch shell', 'us', 'woergl gmbh,', 'its assets also', 'stabilizes plasma using', 'thessaloniki-', ', washington,', 'in mongstad', 'block r,', 'massa carrara,', 'gard,', 'petrobras card', 'ukraine.', 'a nd', 'st. john', 'del norte sa', ', and phillips', 'located in mississippi', '2.6 million acres', 'sevkomneftegaz ooo', 'under monoprix', '1965', 'lulu', "generale d'entretien", 'of kkr', 'in cheltenham,', 'or 28', 'cotco', '2612a (part', 'lithuania, is', 'fiordosur sa is', 'offers port', 'the czech', '2006 and', 'provide limitless', 'netherlands) bv', 'italy through the', 'the saint louis', 'northeast british columbia', 'and france', 'colorado', '. enoch', 'in sydney,', '1985.', 'is a carbon', 'and silver', '2020 and is', 'in arapoti', 'the yamal nenetsk autonomous district', ', mtbe', 'located in austria', 'athabasca land holdings', 'samburgskoye,', 'vietnam, thailand', 'and umm lulu', 'pranhita-godavari', 'nacional de oleoductos', 'bijgaarden', 'bolivia, owns', 'lima,', 'p1929 & p2304', 'internacional sa,', 'with 264', 'cruz alta,', 'sudan.', 'of encana', 'of cia', 'day (kboe', 'caney and upper', 'san miguel pale', 'undan/darwin', ', georgia,', 'across 18 states', 'barrel per day', 'suvarnabhumi airport', 'county, oklahoma', 'and repsol', ', arizona.', 'in cholburi,', 'kajhu', 'canton, ohio', 'oklahoma, tennessee', 'wilmington,', 'is rich', 'ltd is an', 'in 1983 and', 'montney of northeast', 'project and nsw', 'wayne,', 'located in curitiba', 'saipem', 'and georgia', 'and nova', 'karabashskie-6 ooo is', ', cupiaga', 'hizmetleri', 'de janeiro,', 'in etagnieres', 'atyrau.', 'deves insurance pcl', 'clichy', 'quebec, provides', 'including the bab', 'in austin,', 'of onhym', 'carbonvert inc and', 'boundi field is', 'raffineriegesellschaft mbh is', 'approximately 313,000 barrel', 'rwxe participacoes', 'it has more', 'eolicas riojanas sl', 'located in algeria', 'montana, is', 'feistein ccs', 'termobahia', 'guarani sa,', '1997 and', 'hunnu coal ltd', 'lensk,', '15.1 bln boe', 'help', 'argentino', 'under narbheram vishram', '2006 and is', 'austria. located', 'alicante,', '400 million', 'in may 2018', 'portfolio of 29', 'muro gold and', '/p33', "gray's inn", 'ii sp zoo', 'chungbuk, south', '1846', 'used in the', 'acs is headquartered', 'in saskatchewan and', 'capacity of 70mw', 'of 3,765 square', 'it has three', 'de hidrocarburos sa', 'gentil,', 'ypf', ', provides postal', 'kaboom', 'cagliari', ', shoe', 'calpam bv is', 'a 180,000', 'gs corona co ltd', 'chile sa provides', 'europe amounting', 'headquartered in rome', 'in rome', 'march 1990', 'based in santiago', 'fields of magellan', 'mangalore, india', ', silver', '; primary', 'snam rete', 'recuperacao secundaria', 'maracaibo,', 'arkansas, virginia', 'it also owns', 't ...

# %%
new_capabilities
# Out:
# {'dakota. the',
#  'global portfolio',
#  'mfc',
#  'brasilia and',
#  'dakota within',
#  'principal creditos hipotecarios',
#  'in kitimat',
#  'roncador field of',
#  'august 2011',
#  'and peroxides',
#  'gaz',
#  'in angola',
#  'pallonji infrastructure capital',
#  '220,000 barrel',
#  'americas inc',
#  '(wilga park',
#  'in athens,',
#  'resinas sl is',
#  'enerji sanayi ve',
#  'located in bogota',
#  'fibers brand names',
#  'and two breweries',
#  ', home',
#  'led sl is',
#  'omv ag',
#  'caarapo ltda',
#  'hindustan',
#  'portugal, provides',
#  'company produces acrylonitrile',
#  'to 1,200 mm',
#  'blocks included block',
#  'located in ijmuiden',
#  'in saskatchewan',
#  'by equinor',
#  'in libya',
#  'renouvelables sarl is',
#  'bv will',
#  'venture between mitsubishi',
#  'asia) pcl',
#  'valdesolar hive sl',
#  'in palo',
#  'portfolio includes such',
#  ', 1954',
#  'of equinor brasil',
#  'pune,',
#  'gerber products',
#  'founded on march',
#  'brasiliano distribuidora sa',
#  'michigan, us',
#  'located in accra',
#  'pcl, located',
#  'bac thor',
#  'publisher. it',
#  '15th convention',
#  'shi tokyo,',
#  'fpso mystras producao',
#  '5a was',
#  'in boulder,',
#  'can be used',
#  'and wholesale iron',
#  'includes 50%',
#  'in norway,',
#  'attiki',
#  'msts',
#  'located in uganda',
#  'and abrasive',
#  'by pt bahari',
#  'located in warsaw',
#  'royal dutch shell',
#  'us',
#  'woergl gmbh,',
#  'its assets also',
#  'stabilizes plasma using',
#  'thessaloniki-',
#  ', washington,',
#  'in mongstad',
#  'block r,',
#  'massa carrara,',
#  'gard,',
#  'petrobras card',
#  'ukraine.',
#  'a nd',
#  'st. john',
#  'del norte sa',
#  ', and phillips',
#  'located in mississippi',
#  '2.6 million acres',
#  'sevkomneftegaz ooo',
#  'under monoprix',
#  '1965',
#  'lulu',
#  "generale d'entretien",
#  'of kkr',
#  'in cheltenham,',
#  'or 28',
#  'cotco',
#  '2612a (part',
#  'lithuania, is',
#  'fiordosur sa is',
#  'offers port',
#  'the czech',
#  '2006 and',
#  'provide limitless',
#  'netherlands) bv',
#  'italy through the',
#  'the saint louis',
#  'northeast british columbia',
#  'and france',
#  'colorado',
#  '. enoch',
#  'in sydney,',
#  '1985.',
#  'is a carbon',
#  'and silver',
#  '2020 and is',
#  'in arapoti',
#  'the yamal nenetsk autonomous district',
#  ', mtbe',
#  'located in austria',
#  'athabasca land holdings',
#  'samburgskoye,',
#  'vietnam, thailand',
#  'and umm lulu',
#  'pranhita-godavari',
#  'nacional de oleoductos',
#  'bijgaarden',
#  'bolivia, owns',
#  'lima,',
#  'p1929 & p2304',
#  'internacional sa,',
#  'with 264',
#  'cruz alta,',
#  'sudan.',
#  'of encana',
#  'of cia',
#  'day (kboe',
#  'caney and upper',
#  'san miguel pale',
#  'undan/darwin',
#  ', georgia,',
#  'across 18 states',
#  'barrel per day',
#  'suvarnabhumi airport',
#  'county, oklahoma',
#  'and repsol',
#  ', arizona.',
#  'in cholburi,',
#  'kajhu',
#  'canton, ohio',
#  'oklahoma, tennessee',
#  'wilmington,',
#  'is rich',
#  'ltd is an',
#  'in 1983 and',
#  'montney of northeast',
#  'project and nsw',
#  'wayne,',
#  'located in curitiba',
#  'saipem',
#  'and georgia',
#  'and nova',
#  'karabashskie-6 ooo is',
#  ', cupiaga',
#  'hizmetleri',
#  'de janeiro,',
#  'in etagnieres',
#  'atyrau.',
#  'deves insurance pcl',
#  'clichy',
#  'quebec, provides',
#  'including the bab',
#  'in austin,',
#  'of onhym',
#  'carbonvert inc and',
#  'boundi field is',
#  'raffineriegesellschaft mbh is',
#  'approximately 313,000 barrel',
#  'rwxe participacoes',
#  'it has more',
#  'eolicas riojanas sl',
#  'located in algeria',
#  'montana, is',
#  'feistein ccs',
#  'termobahia',
#  'guarani sa,',
#  '1997 and',
#  'hunnu coal ltd',
#  'lensk,',
#  '15.1 bln boe',
#  'help',
#  'argentino',
#  'under narbheram vishram',
#  '2006 and is',
#  'austria. located',
#  'alicante,',
#  '400 million',
#  'in may 2018',
#  'portfolio of 29',
#  'muro gold and',
#  '/p33',
#  "gray's inn",
#  'ii sp zoo',
#  'chungbuk, south',
#  '1846',
#  'used in the',
#  'acs is headquartered',
#  'in saskatchewan and',
#  'capacity of 70mw',
#  'of 3,765 square',
#  'it has three',
#  'de hidrocarburos sa',
#  'gentil,',
#  'ypf',
#  ', provides postal',
#  'kaboom',
#  'cagliari',
#  ', shoe',
#  'calpam bv is',
#  'a 180,000',
#  'gs corona co ltd',
#  'chile sa provides',
#  'europe amounting',
#  'headquartered in rome',
#  'in rome',
#  'march 1990',
#  'based in santiago',
#  'fields of magellan',
#  'mangalore, india',
#  ', silver',
#  '; primary',
#  'snam rete',
#  'recuperacao secundaria',
#  'maracaibo,',
#  'arkansas, virginia',
#  'it also owns',
#  'tcgi',
#  'loire',
#  '(haynesville',
#  'of nonresidential',
#  'located in piscataway',
#  'shi, hokkaido',
#  'export to global',
#  'and toilet',
#  ', kaybob',
#  'same day',
#  'fukuoka-shi',
#  'neponyatnoye',
#  'noreco owns 4.36',
#  'state college',
#  ', gabon.',
#  'located in wayne',
#  'bil cubic',
#  'dicsount',
#  'general sekiyu kk',
#  'chipmunk in alberta',
#  'which includes primary',
#  'activation jetting',
#  'montana. the',
#  'of petrovietnam',
#  'reliance',
#  'in gorizia,',
#  'uses phased arrays',
#  ', lloydminster',
#  'has interests in',
#  'moncure',
#  'cheltenham',
#  'assets also include',
#  'simonop 1',
#  ', bizkaia,',
#  'kamu',
#  'intelligent',
#  '238, located',
#  'called kliks',
#  'columbia,',
#  'founded in april',
#  'somnath district',
#  'in niche thermoplastic',
#  'ames, iowa',
#  'istanbul, turkey',
#  'in the philippines',
#  'by nisource',
#  'and issues petrocard',
#  'and rayong',
#  'provide animal',
#  'in portugal.',
#  'ekologiya',
#  'piterstroy",',
#  'barcelona',
#  'located in goias',
#  'founded in 1957',
#  'founded in 1963',
#  'and antifreeze',
#  'field became part',
#  'borneo bv',
#  'including fibrex',
#  'neptune energy group',
#  'in guyana.',
#  'is a',
#  'depoculuk hizmetleri as',
#  'brisbane, queensland',
#  ', nigeria',
#  ', washington',
#  'bend ccs',
#  'plots of',
#  'it covers a',
#  'south africa assets',
#  '), preobrazhensky',
#  '1979 and',
#  'of moex north',
#  'estate socimi',
#  'mine',
#  'and 3a',
#  'allnex gmbh is',
#  'sihirgaz ticaret ve',
#  'on rue trinquet',
#  'owned by niko',
#  'y suministro de energia sl',
#  'and the balearic',
#  'bardahl india ltd',
#  'called olefins.',
#  'chiang',
#  'located in trento',
#  'in 1956.',
#  'households to access',
#  'medellin',
#  ', kazakhstan',
#  'the fayetteville',
#  'centered on the',
#  'demolished and returned',
#  'nvestment holding company',
#  'demand response',
#  'burglary',
#  ', 2000',
#  'vale do',
#  'tri tunggal',
#  'to zeebrugge in',
#  'residue and',
#  'entities that',
#  'londsdale, australia',
#  'ottmarsheim, france',
#  'in japan.',
#  'interconnector (',
#  'blocks 5 and',
#  'argentina',
#  'and crystal sugar',
#  'its other',
#  'baku',
#  'and london.',
#  'strongcem is',
#  'in south korea',
#  'ireland. it',
#  'portfolio of sao',
#  'of bunge',
#  'located in linz',
#  'in 1972',
#  'dhamma',
#  'fibras',
#  'and massachusetts',
#  'materia inc',
#  'cfc, fiduciaria',
#  'rioja.',
#  'and brisbane.',
#  'enerji sanayi',
#  'the dallas',
#  'bolivia,',
#  'and its derivates',
#  ', high retardance',
#  'in mauritius.',
#  'nv is',
#  'in 1970 and',
#  'founded in 2015',
#  'acetone for use',
#  'australia (wa',
#  'in kansas',
#  'canned products such',
#  'chiang mai',
#  'derivates used',
#  'uk, norway',
#  'bois et',
#  'of guyana',
#  'ventilating and air',
#  'us, a',
#  'baltyk',
#  'egypt, a',
#  'of canned seafood',
#  'des bois',
#  ', through amont',
#  'gestora de participacoes',
#  'armazenagem',
#  ', guara,',
#  'internacional sa',
#  'menlo',
#  'its 914',
#  ', michigan,',
#  'renova',
#  'bu hasa',
#  'loire, france',
#  'andinas',
#  'tantalum and',
#  'huallaga, and',
#  'statoil asa,',
#  'baha',
#  'issues petrocard to',
#  'in ribeirao preto',
#  '. it serves',
#  'gia lai,',
#  '35 to 65',
#  'thousands of households',
#  'and india.',
#  'grenoble, france',
#  'madrid, and',
#  'aberdeen,',
#  'it is close',
#  '1999',
#  'australia, of',
#  'of tonon bioenergia',
#  'haag, netherlands',
#  'lpg to',
#  '537,',
#  'zoriion communication pvt',
#  '1978 and is',
#  'makati, philippines',
#  ', gold eagle',
#  'in 1984.',
#  'return',
#  'alberta and',
#  'june 2005 and',
#  'distribuidora',
#  'in baunatal',
#  'talisman north',
#  'ecuador cia',
#  'the kamchatka and',
#  'church & dwight',
#  'specialty resins business',
#  'along the entire',
#  'mexico assets',
#  'portfolio of encana',
#  'insomnia and',
#  'performing loans',
#  'senegal.',
#  'states unconventional',
#  "'s 47.1",
#  'of inductive coils',
#  'gestioni',
#  'refineria la pampilla',
#  '%, det',
#  "l'isle-jourdain",
#  'groot',
#  ', it,',
#  'tripoli, libya',
#  'in indonesia:',
#  'by global',
#  '-nenets autonomous',
#  'to specific',
#  'wholesaler of cellulosic',
#  'statoil asa',
#  'and marseille',
#  'fivory',
#  'mexico to other',
#  'april 2016',
#  'minh',
#  'paulo state.',
#  'trac-x',
#  'centro sa',
#  ', including',
#  'chullora,',
#  'cement used for',
#  'kos dehseh (',
#  'is equivalent',
#  'in bangkok to',
#  'franklin',
#  'from its own',
#  'in zurich,',
#  'province',
#  'uk 14',
#  'egypt, is',
#  '025, located',
#  ', 8',
#  'had remaining 73.593',
#  'in rotterdam',
#  'located in mumbai',
#  'somnath district of',
#  'germany, spain',
#  'zurich,',
#  'sealants, and',
#  'portfolio of isemaren',
#  'in hachioji',
#  '; refine',
#  'tanzania',
#  'business of marinos',
#  'edeka zentrale',
#  'del valle sa',
#  ', specialty resins',
#  'in 1949',
#  ', townsville,',
#  'chang group holding',
#  'the tengiz',
#  'boundi',
#  'arkansas, oklahoma',
#  'undisclosed us',
#  'mpeg streaming',
#  'ctida srl',
#  'life insurance company',
#  'that enable',
#  'novel crystal technology',
#  'in october 2009',
#  'that sends out',
#  'desenvolvimento de',
#  'in the sangu',
#  'saskatchewan',
#  'without any confusion',
#  'kompaniia slavneft',
#  'to early',
#  '7500 post around',
#  'name guallarauco',
#  'es salaam',
#  'others.',
#  'located in northern',
#  'allnex offers a',
#  'antofagasta, vina',
#  'in central texas',
#  'twenty three',
#  ', queensland,',
#  'northeast of fort',
#  'bucuresti',
#  "brazil's",
#  'shi fukuoka',
#  'krasnoselkup, the',
#  'catan empreendimentos',
#  'repsol sa',
#  'john, new',
#  'insulation coatings',
#  ' szamitastechnikai',
#  'gold eagle,',
#  'coventry',
#  'has more than',
#  'baan chang',
#  'the prolific',
#  ', maleicanhydrite and',
#  'include a',
#  ', us.',
#  'easy for hundreds',
#  'tritton',
#  'tiszantuli gazszolgaltato zrt',
#  'and 18',
#  'midwestern united states',
#  'holding as is',
#  'states. it',
#  'kdv bv',
#  'minas gerais,',
#  'of tranzen',
#  'phibro llc,',
#  'in northern new',
#  'the i-35 corridor',
#  'kigali, rwanda',
#  'explortaion, prodn',
#  'specialties include',
#  'manufacturer of plastic',
#  'm boundi',
#  'krasnoyarsk',
#  'do sul',
#  '1968 and',
#  'south africa,',
#  '-german products',
#  'of shanxi',
#  'albania,',
#  'africa and southeast',
#  'pta indonesia pt',
#  'condensate fields',
#  'in chile',
#  'fowler, indiana',
#  'in madagascar',
#  'in 2003',
#  ', smatrics',
#  'cartagena, colombia',
#  ', argentina',
#  'lumlukka terminal',
#  'petroquisa},',
#  'videocon mozambique rovuma',
#  'charging network',
#  'the montreal east',
#  'gathering as well',
#  'by global clearspans',
#  'ltd and pioneer',
#  'block.',
#  'kb space holdings , inc.',
#  'block 5a was',
#  'a 5 mmtpa',
#  "d'entretien des",
#  '4,000 km and',
#  'gorgon',
#  "russneft' pao",
#  'reliance industries ltd',
#  'in 1961',
#  'company has two',
#  'in curitiba,',
#  'oklahoma, is',
#  'lieferdienst gmbh',
#  'manufacture rubber gloves',
#  'nsw',
#  'basell canada inc',
#  'in louisville,',
#  'comercial sa located',
#  'copenhagen,',
#  'torinese',
#  'located in chuo',
#  '46 fields',
#  'it has 47',
#  'of edmonton',
#  'montt, and',
#  'mexico, is',
#  '41 covering',
#  'tullow',
#  'to suvarnabhumi airport',
#  'pranhita-',
#  'block covers 672',
#  'albania assets',
#  'unnamed driver and',
#  'in zierbena,',
#  'is more than',
#  'in 2015.',
#  'gruppo finservice',
#  ', colombia and',
#  'louisville, kentucky',
#  'unity fpso of',
#  '-verbundnetz',
#  '0.629 mil barrels',
#  'day. it',
#  'muro gold',
#  'co2 - sequesterd aggregate',
#  'gazovaia',
#  'es salaam,',
#  'in avon,',
#  'in august 1994',
#  'furnibest',
#  'located in brasov',
#  'brazzaville),',
#  'business of afab',
#  'at nuevo',
#  'kentucky, new',
#  'located in ichihara',
#  'egypt and',
#  'sulbrasileira de',
#  'greater nile',
#  'oklahoma city,',
#  'in basra,',
#  'bermolonga',
#  'monoprix brand.',
#  'founded in 2010',
#  'zao "yevrotek',
#  'kompaniia ao is',
#  'of 3.1',
#  'that are',
#  'continuous capture of',
#  'in 2001',
#  'are sent omnidirectional',
#  'more than 5,500',
#  'founded in 2017',
#  'assets of landmark',
#  '1995 and is',
#  'tokyo denkai',
#  'headquartered in madagascar',
#  'rwanda and four',
#  'brands include san',
#  ') pcl is',
#  'lloydminster in',
#  'colorado and the',
#  'tennessee, alabama',
#  'distribucija',
#  ', silver and',
#  '; gladstone',
#  'athabasca land',
#  '1992.',
#  'and 11.75 mw',
#  'founded in 1982',
#  '180,000 contiguous net',
#  'is also',
#  ', chile.',
#  'north canton,',
#  'spain, is',
#  'conceicao,',
#  'of saipem spa',
#  ', morocco.',
#  'kigali',
#  'beninoise des',
#  'is close',
#  'based in saitama',
#  'danilovskoye',
#  'of koninklijke dsm',
#  'dunkerque sa manufactures',
#  'dakota and',
#  'golden, colorado',
#  'provides a list',
#  'broken contracts',
#  'in alexandria,',
#  'northern xingan',
#  'renasci nv',
#  'thai',
#  'sugar and alcohol',
#  'major segments,',
#  'foreigner',
#  'including 11',
#  'retardance',
#  'athens, greece',
#  'purified terephthalic acid',
#  ': west siberia',
#  'tranzen',
#  'road marking pains',
#  'kofiau',
#  'regasification terminal,',
#  'gubkinskiy,',
#  'in leipzig,',
#  'triunfo,',
#  'petrohawk',
#  'it is devoted',
#  'chicago,',
#  'gujarat, faridabad',
#  'nesika',
#  'atyrau. the',
#  'delta where',
#  'williston, north',
#  ', colombia.',
#  'and the dorstfontein',
#  'gevo inc',
#  'eagle ford acreage',
#  'in la spezia',
#  'thousands of',
#  'license, 20.273',
#  'in enoch.',
#  'gabon',
#  '2015.',
#  ', colorado provides',
#  'households to',
#  'brasil ltda is',
#  'chesterfield, uk',
#  '2002',
#  'a 111 km2',
#  'societe de la',
#  'ulsan, south',
#  'than 29,000 km',
#  'port of bilbao',
#  'and nylon-6.',
#  'guinea',
#  'tonner bag',
#  'in chita,',
#  'lyon grand',
#  'focuses on',
#  'of nec',
#  'it was discovered',
#  'the puesto hernandez',
#  'of raiznext',
#  'quenchant',
#  'it owns two',
#  'aparthotel',
#  'approximately 150,000',
#  'remelter',
#  'ticaret ve',
#  'of 5.563 bil',
#  'of ptt',
#  'maleicanhydrite and other',
#  '048e,',
#  'owns the hotell',
#  'bayernoil raffineriegesellschaft',
#  ', ukraine.',
#  'morocco, brazil',
#  'founded in october',
#  'of 5,649',
#  'us and',
#  'cartagena',
#  'postmaster srl',
#  'part of kazakhstan',
#  'generation assets with',
#  'levallois',
#  '19, 2014',
#  ', latin',
#  'montara project,',
#  'located in oostende',
#  'bp has',
#  'direct pty ltd',
#  'szolgaltato korlatolt  ',
#  'surface active',
#  'as pe and',
#  'south china',
#  'statoil canada',
#  'pt sentika',
#  'boron',
#  'in september 2013',
#  'petra nova parish',
#  'renasci oostende nv',
#  'from 25 to',
#  'oml 53',
#  'huntingdon,',
#  'and 10.',
#  'rak mae co',
#  'charvet',
#  'dynachisso thai',
#  'azienda sviluppo',
#  'baltyk iii',
#  'located in zagreb',
#  'united states through',
#  'uganda ltd',
#  'malt liquors',
#  'in rotterdam,',
#  'license of china',
#  'dehseh',
#  'homes across',
#  'headquartered in brooklyn',
#  'by tamoil italia',
#  'located in butler',
#  'samburgskoye',
#  'a hungary-',
#  'in santarem,',
#  'which are transmitted',
#  'pty ltd,',
#  ', norway.',
#  ', murphy sabah',
#  'the license covers',
#  'brazil. it',
#  'also does import',
#  'approximately 4.8 mil barrel',
#  'july 19 , 2007',
#  'gilg',
#  'pbl bypass,',
#  'venture of',
#  'austrian',
#  'san mig',
#  'clichy, france',
#  'dsm nv,',
#  'and midstream',
#  ', denmark',
#  'silver and gold',
#  ', alaska,',
#  'west texas,',
#  'mexico portfolio',
#  'northeast british',
#  'eni (18.52',
#  'kazakhstan city',
#  'amberjack',
#  'mcmurray,',
#  'in 1944',
#  'block 16',
#  'in november 2001',
#  'of mossi',
#  'in july 2013',
#  'stekene',
#  'bottling services pty',
#  'conceicao, brazil',
#  'and marseille,',
#  'muroran',
#  'juan, san',
#  'levallois perret',
#  'interests in 46',
#  'states. its',
#  ', florim',
#  'new guinea',
#  'based of',
#  'kliks,',
#  'ginebra',
#  'bermolonga accumulation',
#  '. the upcycled',
#  'americas and',
#  'approximately 234,000 barrel',
#  'oml 53,',
#  ', california is',
#  'located in baku',
#  'area covering approximately',
#  'in lensk,',
#  'nedpower mount storm llc',
#  'the portfolio includes',
#  'canada partnership is',
#  'm&bm express',
#  'de la sierra',
#  'bakken and',
#  'transshipment llc is',
#  'communication cables',
#  'in tomakomai',
#  ', maryland,',
#  'pedranopolis, sao',
#  'company offers cloud',
#  'k5a license,',
#  'it has',
#  'map ta phut',
#  'global power synergy pcl',
#  'malt',
#  'springs, new',
#  '38',
#  'totalenergies',
#  'located in beringen',
#  'holds 24%',
#  'kaboom cleaning',
#  '194',
#  'providencia,',
#  'are mostly asian',
#  'in the nonferrous',
#  'treasury, banking',
#  'block of ypf',
#  'haltenbanken area which',
#  'its five',
#  'consist of 200',
#  'parking sem parar',
#  'sl{enex}',
#  'located in canada',
#  '125 km',
#  'slovak',
#  '& 6706/12',
#  'mogdinsky,',
#  'paris 15th convention',
#  'and alberta',
#  '24,',
#  'buglaria eood,',
#  'licence 238,',
#  ', wiriagar',
#  ', a',
#  'brazil. its',
#  'percent share in',
#  'acs is',
#  'day (boepd',
#  'ibri, oman',
#  'refap}',
#  'tennessee and',
#  'west siberian',
#  'austria. the',
#  'called kliks,',
#  'concrete applications',
#  'the marsden',
#  ', jute',
#  '6.7 trillion cubic foot',
#  'germany.',
#  'an independent',
#  'that focuses on',
#  'puteaux, france',
#  ', the 80-',
#  'township, pennsylvania',
#  'neftegazovaia kompaniia slavneft',
#  'santa catarina',
#  'pension & annuity',
#  'joslyn',
#  'jaragua do sul',
#  'cekomastik kimya sanayi',
#  '31.12.2012 the',
#  'international sarl,',
#  'coating and engraving',
#  'inorganic paint pigments',
#  ', franco and',
#  ', between dallas',
#  'switzerland',
#  'in brasov,',
#  'track record of',
#  ', cruz alta',
#  '5a is',
#  'on july',
#  'nationwide network',
#  'its five key',
#  'kiatnakin bank pcl',
#  '& offloading florence',
#  'kitimat, canada',
#  'australia and the',
#  'blocks are located',
#  'sagaz is',
#  'co inc',
#  'valentia and',
#  'mitra aneka rezeki',
#  'license covers the',
#  'illinois,',
#  'fils charvet sa(total',
#  'pedranopolis',
#  'amargo sur',
#  'of rockdale marcellus',
#  'distribuidora sa,',
#  'supreme quality',
#  'june 2006 and',
#  'based in bangkok',
#  'for city',
#  'midia block',
#  'canada, france',
#  'to the intermountain',
#  'internet access',
#  'located in valencia',
#  'is a non',
#  'e tecnologia de',
#  ': the caspian',
#  'events more',
#  'user collects',
#  'capacity of 300',
#  'paulo, rio',
#  'business of comest',
#  'company sanofi-',
#  'march 24',
#  'located in albacete',
#  'record of increasing',
#  'fields in',
#  'manila, philippines',
#  ', and asia',
#  'in malaysia.',
#  'june 2001',
#  'videocon',
#  'in january 2011',
#  'licenses in papua',
#  'marmara depoculuk hizmetleri',
#  ', egypt.',
#  ...}

# %% [markdown]
# # METHOD 4

# %%
import pandas as pd
import spacy
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer
import numpy as np
from tqdm import tqdm  # Import tqdm for progress bars

# Load data
df_train = pd.read_excel("TrainingSet.xlsx")
df_capabilities = pd.read_excel("List of capabilities.xlsx")

# Load Spacy Model with NER
nlp = spacy.load('en_core_web_sm')

# Load a pre-trained Sentence Transformer model
model = SentenceTransformer('all-MiniLM-L6-v2')

def extract_phrases(text):
    doc = nlp(text)
    # Generate meaningful n-grams and specific named entities
    phrases = set()
    for ent in doc.ents:  # Use named entities
        if ent.label_ in ['ORG', 'PRODUCT', 'GPE', 'LOC']:  # Filter for specific entity types
            phrases.add(ent.text.lower())

    # Generate n-grams filtering out stop words and punctuation
    n_grams = [" ".join([token.lemma_ for token in doc[i:i+3] if token.is_alpha and not token.is_stop]) for i in range(len(doc)-2)]
    n_grams.extend([" ".join([token.lemma_ for token in doc[i:i+2] if token.is_alpha and not token.is_stop]) for i in range(len(doc)-1)])
    phrases.update(filter(None, n_grams))  # Filter empty strings

    return list(phrases)

# Process text data
df_train['phrases'] = df_train['Target Business Description'].apply(extract_phrases)
df_capabilities['phrases'] = df_capabilities['Technologies/Skills'].astype(str).apply(extract_phrases)

# Flatten and vectorize capabilities
flat_capabilities = [item for sublist in df_capabilities['phrases'] for item in sublist]
capability_embeddings = np.array([model.encode(phrase) for phrase in tqdm(flat_capabilities, desc='Encoding Capabilities') if phrase.strip()])

# Identify new capabilities
new_capabilities = set()
similarity_threshold = 0.2  # Lower threshold to be more selective

for phrases in tqdm(df_train['phrases'], desc='Comparing Phrases'):
    for phrase in phrases:
        if phrase.strip():
            phrase_emb = model.encode(phrase)
            sims = cosine_similarity([phrase_emb], capability_embeddings)
            if all(sim < similarity_threshold for sim in sims[0]):
                new_capabilities.add(phrase)

print("New capabilities to consider adding:", new_capabilities)
# Out:
# /Users/aaryanshah/Library/Python/3.9/lib/python/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Encoding Capabilities: 100%|██████████| 692/692 [00:11<00:00, 62.13it/s]
# Comparing Phrases: 100%|██████████| 2532/2532 [24:59<00:00,  1.69it/s]
# New capabilities to consider adding: {'Chipmunk', 'Montpellier', 'Kentucky Mississippi', 'Midwestern United States', 'Kentucky New', 'Holding Germany II', 'health education', 'Minnetonka', 'Offloading Florence', 'provide online information', 'China National', 'locate Peru', 'Cruz del', 'Dynachisso Thai', 'Poland locate', 'block Kosmos', 'Light Gold', 'XIX Neptun', 'Zierbena Bizkaia', 'Budapest', 'locate France', 'toreador hungary ltd', 'locate Sofia', 'Minnetonka Minnesota', 'southern United States', 'brand include San', 'locate Feldkirch', 'treasury banking', 'locate Louisville', 'West Australia', 'Cruz De La', 'Settimo Torinese', 'Nagaoka Karyoku', 'Doha Qatar', 'select asset', 'border Norway', 'locate Mississauga', 'Bagnolet France', 'Montney northeast', 'Romans France', 'Brazil Azerbaijan', 'locate Frankfurt', 'Mendoza Argentina', 'Papua Indonesia', 'Associati Societa di', 'Block Romania', 'locate Centennial', 'comprise Vibo', 'Holding BVBA', 'Seri Begawan', 'Midwest', 'des Mille', 'Ibereolica Renovables', 'locate Gurgaon', 'Chernichny block', 'Uttar Pradesh', 'Toreador Hungary Ltd', 'zierbena-bizkaia', 'Participacoes Sociais SA', 'portfolio Isemaren', 'Netherlands Norway', 'Aparecida Taboado', 'Vadodara Gujarat', 'UAB locate', 'Reading UK', 'burglary insurance', 'Anglo Siberian', 'locate Liberia', 'Beringen', 'block 1', 'array transfer', 'Tobago', 'place de la republique', 'sur Avre', 'Mime Distribuidora de', 'Frigorifico Fiordosur', 'Virginia own', 'mail Croatian', 'region Dobrogea', 'Biochemtex Beta', 'continent area', 'engraving metal', 'TotalEnergies EP Canada', 'Brasileiro SA', 'Burnaby British', 'View Illinois', 'Neuquen City Neuquen', 'locate Weinheim', 'locate Beijing', 'saint-priest', 'Actividades de Construccion', 'locate Australia', 'include Tenzan', 'porto alegre', 'provide life', 'purpose vechicle', 'Empreendimentos e Participacoes', 'China Australia', 'locate Honolulu', 'Colombia Peru', 'Cusiana Cupiagua', 'idrocarbury italia srl', 'Fibras SA', 'Energia Participaciones', 'locate Tupi', 'locate Velizy', 'Pallonji Infrastructure', 'block locate', 'Concepcion Temuco', 'Greece', 'locate Portugal', 'locate Wayne', 'Japan include', 'Namibia engage', 'asset Apache', 'North texas', 'possess nationwide', 'de Espana SL', 'Horse Cerveza', 'Sur Fuerte', 'Shell Ghana Ltd', 'Cerveza', 'Thorntons Inc', 'Mereenie', 'new mexico', 'Ahmedabad', 'export activity', 'Shetland Islands', 'Eolicas Riojanas', 'locate Neustadt', 'Brazil worldwide', 'Romania provide', 'Equinor Brasil', 'Unity FPSO', 'turukhansk', 'Global Clearspans', 'Gazprom Neft', 'de Espana', 'mereenie', 'Chennai India', 'rwanda', 'UTEJF locate', 'Iputi Empreendimentos', 'shetland islands', 'albania', 'Velizy Villacoublay', 'makati city', 'locate Wilmington', 'guatemala', 'insurance burglary', 'locate Beaumont', 'japan', 'New Brunswick', 'Philippines provide', 'energie Renouvelables SARL', 'northern territory', 'Arica Coyhaique', 'es Szamitastechnikai', 'South East Asia', 'locate Queensland', 'Quebec provide', 'Rio De Janeiro', 'SARL locate', 'Sequesterd Aggregate', 'Southeast Kalimantan', 'amoco mitsui', 'Utah Louisiana', 'Goias Brazil', 'Gerais', 'New Jersey', 'Bronberger Kessler', 'comprise Kalkbult', 'Equinor include', 'cover tire', 'locate Ibirite', 'tunisia', 'Tasmania', 'Sarnia', 'copenhagen', 'imjuiden', 'Loire France', 'locate Saint', 'Jisike', 'Frigorifico Fiordosur SA', 'UK Norway', 'Sycamore formation', 'locate Santiago', 'locate Aveiro', 'operate Narrabri', 'Thai PET', 'Mendoza San', 'multiple simultaneous event', 'locate Yangju', 'locate Mozambique', 'Copenhagen Denmark', 'Calysta Inc', 'spain', 'Clarence Moreton', 'Uganda', 'guyana', 'East Africa', 'Saraburi Lumlukka', 'decarbonize asset', 'DEA Deutsche', 'German Products PCL', 'plus domestic', 'Ohio own', 'Ghisolfi', 'locate Cairo', 'locate Ivanka', 'Az Zhara', 'locate Temple', 'Neponyatnoye', 'locate Providencia', 'locate Texas', 'taino', 'British Colombia', 'Neftyanaya Kompaniya Alyans', 'locate Mi ...

# %%
new_capabilities
# Out:
# {'Chipmunk',
#  'Montpellier',
#  'Kentucky Mississippi',
#  'Midwestern United States',
#  'Kentucky New',
#  'Holding Germany II',
#  'health education',
#  'Minnetonka',
#  'Offloading Florence',
#  'provide online information',
#  'China National',
#  'locate Peru',
#  'Cruz del',
#  'Dynachisso Thai',
#  'Poland locate',
#  'block Kosmos',
#  'Light Gold',
#  'XIX Neptun',
#  'Zierbena Bizkaia',
#  'Budapest',
#  'locate France',
#  'toreador hungary ltd',
#  'locate Sofia',
#  'Minnetonka Minnesota',
#  'southern United States',
#  'brand include San',
#  'locate Feldkirch',
#  'treasury banking',
#  'locate Louisville',
#  'West Australia',
#  'Cruz De La',
#  'Settimo Torinese',
#  'Nagaoka Karyoku',
#  'Doha Qatar',
#  'select asset',
#  'border Norway',
#  'locate Mississauga',
#  'Bagnolet France',
#  'Montney northeast',
#  'Romans France',
#  'Brazil Azerbaijan',
#  'locate Frankfurt',
#  'Mendoza Argentina',
#  'Papua Indonesia',
#  'Associati Societa di',
#  'Block Romania',
#  'locate Centennial',
#  'comprise Vibo',
#  'Holding BVBA',
#  'Seri Begawan',
#  'Midwest',
#  'des Mille',
#  'Ibereolica Renovables',
#  'locate Gurgaon',
#  'Chernichny block',
#  'Uttar Pradesh',
#  'Toreador Hungary Ltd',
#  'zierbena-bizkaia',
#  'Participacoes Sociais SA',
#  'portfolio Isemaren',
#  'Netherlands Norway',
#  'Aparecida Taboado',
#  'Vadodara Gujarat',
#  'UAB locate',
#  'Reading UK',
#  'burglary insurance',
#  'Anglo Siberian',
#  'locate Liberia',
#  'Beringen',
#  'block 1',
#  'array transfer',
#  'Tobago',
#  'place de la republique',
#  'sur Avre',
#  'Mime Distribuidora de',
#  'Frigorifico Fiordosur',
#  'Virginia own',
#  'mail Croatian',
#  'region Dobrogea',
#  'Biochemtex Beta',
#  'continent area',
#  'engraving metal',
#  'TotalEnergies EP Canada',
#  'Brasileiro SA',
#  'Burnaby British',
#  'View Illinois',
#  'Neuquen City Neuquen',
#  'locate Weinheim',
#  'locate Beijing',
#  'saint-priest',
#  'Actividades de Construccion',
#  'locate Australia',
#  'include Tenzan',
#  'porto alegre',
#  'provide life',
#  'purpose vechicle',
#  'Empreendimentos e Participacoes',
#  'China Australia',
#  'locate Honolulu',
#  'Colombia Peru',
#  'Cusiana Cupiagua',
#  'idrocarbury italia srl',
#  'Fibras SA',
#  'Energia Participaciones',
#  'locate Tupi',
#  'locate Velizy',
#  'Pallonji Infrastructure',
#  'block locate',
#  'Concepcion Temuco',
#  'Greece',
#  'locate Portugal',
#  'locate Wayne',
#  'Japan include',
#  'Namibia engage',
#  'asset Apache',
#  'North texas',
#  'possess nationwide',
#  'de Espana SL',
#  'Horse Cerveza',
#  'Sur Fuerte',
#  'Shell Ghana Ltd',
#  'Cerveza',
#  'Thorntons Inc',
#  'Mereenie',
#  'new mexico',
#  'Ahmedabad',
#  'export activity',
#  'Shetland Islands',
#  'Eolicas Riojanas',
#  'locate Neustadt',
#  'Brazil worldwide',
#  'Romania provide',
#  'Equinor Brasil',
#  'Unity FPSO',
#  'turukhansk',
#  'Global Clearspans',
#  'Gazprom Neft',
#  'de Espana',
#  'mereenie',
#  'Chennai India',
#  'rwanda',
#  'UTEJF locate',
#  'Iputi Empreendimentos',
#  'shetland islands',
#  'albania',
#  'Velizy Villacoublay',
#  'makati city',
#  'locate Wilmington',
#  'guatemala',
#  'insurance burglary',
#  'locate Beaumont',
#  'japan',
#  'New Brunswick',
#  'Philippines provide',
#  'energie Renouvelables SARL',
#  'northern territory',
#  'Arica Coyhaique',
#  'es Szamitastechnikai',
#  'South East Asia',
#  'locate Queensland',
#  'Quebec provide',
#  'Rio De Janeiro',
#  'SARL locate',
#  'Sequesterd Aggregate',
#  'Southeast Kalimantan',
#  'amoco mitsui',
#  'Utah Louisiana',
#  'Goias Brazil',
#  'Gerais',
#  'New Jersey',
#  'Bronberger Kessler',
#  'comprise Kalkbult',
#  'Equinor include',
#  'cover tire',
#  'locate Ibirite',
#  'tunisia',
#  'Tasmania',
#  'Sarnia',
#  'copenhagen',
#  'imjuiden',
#  'Loire France',
#  'locate Saint',
#  'Jisike',
#  'Frigorifico Fiordosur SA',
#  'UK Norway',
#  'Sycamore formation',
#  'locate Santiago',
#  'locate Aveiro',
#  'operate Narrabri',
#  'Thai PET',
#  'Mendoza San',
#  'multiple simultaneous event',
#  'locate Yangju',
#  'locate Mozambique',
#  'Copenhagen Denmark',
#  'Calysta Inc',
#  'spain',
#  'Clarence Moreton',
#  'Uganda',
#  'guyana',
#  'East Africa',
#  'Saraburi Lumlukka',
#  'decarbonize asset',
#  'DEA Deutsche',
#  'German Products PCL',
#  'plus domestic',
#  'Ohio own',
#  'Ghisolfi',
#  'locate Cairo',
#  'locate Ivanka',
#  'Az Zhara',
#  'locate Temple',
#  'Neponyatnoye',
#  'locate Providencia',
#  'locate Texas',
#  'taino',
#  'British Colombia',
#  'Neftyanaya Kompaniya Alyans',
#  'locate Mississippi',
#  'locate Vila',
#  'locate southern',
#  'Food PCL',
#  'locate Aparecida',
#  'Acoreana Armazenagem de',
#  'North Canton',
#  'locate Ponta',
#  'Thai Smile',
#  'parque das conchas',
#  'Palo Alto',
#  'Enerco Enerji Sanayi',
#  'Oberhausen',
#  'Houma Louisiana',
#  'Bruderheim Alberta',
#  'printing service include',
#  'Cruz Alta Participacoes',
#  'serve key',
#  'locate Westport',
#  'principal Creditos Hipotecarios',
#  'Sites Testing',
#  'locate Cartagena',
#  'Apache Canada Ltd',
#  'Nuevo Alisal',
#  'Petrobras de Valores',
#  'Yakhinskoye',
#  'Church Dwight',
#  'turkey',
#  'locate Southern',
#  'Ottawa',
#  'Muturi',
#  'list commercial',
#  'Luxembourg France',
#  'locate Edeia',
#  'Parque Eolico',
#  'Clichy',
#  'chiang mai, thailand',
#  'tenement close',
#  'Cheshire',
#  'locate Brussels',
#  'Shapoorji Pallonji Infrastructure',
#  'locate Vienna',
#  'New Guinea',
#  'Petrobras Quimica SA',
#  'Etienne France',
#  'liege',
#  'Bijgaarden',
#  'locate Wiesbaden',
#  'Buenos Aires',
#  'Uniboard USA',
#  'Kingdom own',
#  'locate Hajduszoboszlo',
#  'credit card fraud',
#  'Japan Brazil',
#  'Ibirite Brazil',
#  'locate Manila',
#  'locate Chungbuk',
#  'Tiszantuli Gazszolgaltato',
#  'major operator',
#  'Fundo Brazil',
#  'Cairo Egypt',
#  'Istrabenz Holdinska Druzba',
#  'de Ativos',
#  'SEI Servizi',
#  'Peru principally',
#  'Pei San Food',
#  'Nakagami',
#  'iliad',
#  'northampton',
#  'Gorgon Joint',
#  'Strasbourg France',
#  'Brisbane Australia',
#  'array',
#  'locate Minsk',
#  'Marmara Depoculuk',
#  'Koninklijke Dsm Nv',
#  'locate Reading',
#  'Alexandria',
#  'North Carolina',
#  'Timano Pechora',
#  'Shanxi',
#  'Energas SARL',
#  'locate Hungary',
#  'Australia own',
#  'locate Paris',
#  'Alicante Spain',
#  'Taino',
#  'asian American',
#  'develop bone marrow',
#  'Brazzaville',
#  'Mongstad Norway',
#  'Brazil Middle',
#  'wine food',
#  'locate Kazakhstan',
#  'TMB Bank PCL',
#  'suriname',
#  'multi-activation jetting',
#  'decorative paint',
#  'Netherlands Germany',
#  'Worth metroplex',
#  'Videocon Mozambique',
#  'locate Chicago',
#  'primarily Europe',
#  'Sydney New',
#  'issue petrocard',
#  'de Produtos',
#  'Vila Nova Conceicao',
#  'Open Sources',
#  'Tengiz',
#  'madison',
#  'athabasca',
#  'metal closure',
#  'own Saipem',
#  'pittsburg county',
#  'Kristiansund Norway',
#  'Northern Territory',
#  'Nenetsk Autonomous District',
#  'Adelaide South',
#  'locate Sevilla',
#  'Amoco Mitsui PTA',
#  'Temple II',
#  'locate Prahran',
#  'sharing contract own',
#  'british colombia',
#  'Entre Lomas',
#  'Societa di',
#  'san luis',
#  'County West',
#  'alcoholic malt',
#  'Angola Brazil',
#  'locate Cholburi',
#  'locate Piscataway',
#  'Torzhokskiy zavod poligraficheskikh',
#  'Central Asia',
#  'Belt Venezuela',
#  'locate Greece',
#  'locate Surat',
#  'horizontal Niobrara',
#  'Zierbena',
#  'locate Ellensboro',
#  'Forzando',
#  'San Miguel',
#  'UK Ireland',
#  'locate Pleasanton',
#  'provide polyolefin',
#  'hangzhou',
#  'quebec',
#  'la Republique',
#  'Enerco Enerji',
#  'locate Quito',
#  'Kos Dehseh',
#  'locate Khartoum',
#  'Coiron Amargo Sur',
#  'Denmark UK',
#  'khurja',
#  'speyer',
#  'Koto Ku',
#  'beijing',
#  'Montreuil locate',
#  'refap provide',
#  'Idrocarbury Italia',
#  'Ewing New',
#  'Bergen',
#  'singapore',
#  'locate Morocco',
#  'locate Fukuoka',
#  'locate Colorado',
#  'terminal locate',
#  'Pasqualini SA',
#  'automatically locate Cota',
#  'Eolicas Riojanas SL',
#  'Romania own',
#  'non address',
#  'Ate Peru',
#  'printing ink',
#  'Munich Germany',
#  'locate Herzegovina',
#  'Tate Srl',
#  'locate Berlin',
#  'Victoria Peru',
#  'Yamal Nenets',
#  'Sources',
#  'medical consultation',
#  'Castejon Navarra',
#  'gorgon joint venture',
#  'thai-amadeus southeast asia company ltd',
#  'Rhenus Life',
#  'la Raffinerie',
#  'Agip Espana',
#  'locate Moscow',
#  'Nigeria own',
#  'rio de janeiro',
#  'Queensland Northern',
#  'Counties Arkansas',
#  'Priest France',
#  'Tesoro Hawaii',
#  'Sudanese Civil War',
#  'Distribucija Plina Doo',
#  'Jeito Capital SAS',
#  'locate Stavanger',
#  'Mangalia Romania',
#  'locate Benin',
#  'azora capital sl',
#  'predominantly romanian',
#  'Torinese',
#  'Ruakaka New',
#  'Halmahera Kofiau',
#  'entity active',
#  'Palo',
#  'Maracaibo',
#  'Perth Australia',
#  'buenos aires',
#  'nexen inc',
#  'Tecverde Engenharia',
#  'Lille France',
#  'include Leasing Corficolombiana',
#  'northeast British',
#  'Italy provide',
#  'Societa di Ingegneria',
#  'array lead',
#  'locate Dar',
#  'monterey county',
#  'Creditos Hipotecarios SA',
#  'italy',
#  'Rue Trinquet',
#  'compound annual',
#  'neponyatnoye',
#  'locate Trento',
#  'Holladay Utah',
#  'introduce Smart',
#  'New South',
#  'Ichihara Shi',
#  'Caspian West',
#  'product include PBL',
#  'locate Taipei',
#  'mouse keyboard',
#  'use inductive',
#  'La Spezia',
#  'middle magdalena',
#  'Leipzig Germany',
#  'narbheram vishram',
#  'lar espana real estate socimi sa',
#  'Tom Prncipe',
#  'Muroran II',
#  'locate Italy',
#  'Brazil include',
#  'Pedranopolis Sao',
#  'JC et Fils',
#  'manufacture videotape',
#  'Oostende Belgium',
#  'state include',
#  'Praetorium Holding',
#  'tuk ridesharing app',
#  'Anif Austria',
#  'slovak',
#  'Luis Catamarca',
#  'DEA Deutsche Erdoel',
#  'Adagio Aparthotel',
#  'locate Belem',
#  'card fraud',
#  'acre North',
#  'Niobrara Codell',
#  'Lucca',
#  'TonenGeneral Sekiyu',
#  'entire fiber cable',
#  'Klikin deal Spain',
#  'the dominican republic',
#  'operate medical consultation',
#  'San Miguel Foods',
#  'tecnicontrol y gestion  integral s l',
#  'include Turn',
#  'purpose Thailand',
#  'widespread adoption',
#  'Karlstein',
#  'Simarelli',
#  'Bellevue Washington',
#  'locate Bahia',
#  'Shell Neft LLC',
#  'Caarapo Brazil',
#  'Santarem Portugal',
#  'branch CNEA',
#  'de Alcool de',
#  'field focus',
#  'Tonkin cover approximately',
#  'new delhi',
#  'Altares Montney',
#  'locate Seattle',
#  'include Cusiana',
#  'Maranon',
#  'Lensk Russian',
#  'Louisiana Haynesville',
#  'locate Stekene',
#  'locate Ichihara',
#  'Nitta Gelatin',
#  'Energia Participaciones SA',
#  'Santo Brazil',
#  'hamburg',
#  'locate Norway',
#  'ukraine',
#  'Chennai',
#  'Dorstfontein',
#  'PT Federal Karyatama',
#  'San Miguel Pale',
#  'block Madalena',
#  'Viracopos Curitiba',
#  'Nacional de',
#  'locate Guyana',
#  'locate Cambridge',
#  'Mogdinsky Vostochno',
#  'Canada France',
#  'calysta inc',
#  'Beleggingsmaatschappij BV',
#  'eliminate credit',
#  'aspartame sweetener',
#  'orinduik block',
#  'Denmark',
#  'gs platech co ltd',
#  'Roquefort France',
#  'Bangkok Thailand',
#  'include ice cream',
#  'locate Taino',
#  'El Shawish West',
#  'France own',
#  'locate Oklahoma',
#  'East Kalimantan',
#  'baku',
#  'locate Chullora',
#  'Masisa Brasil',
#  'organ transplant',
#  'Zhejiang Chuanhua',
#  'deploy number',
#  'locate Lensk',
#  'Serraria Arapoti',
#  'Guarulhos Recife',
#  'Spazio',
#  'compose Sururu',
#  'Kigali Rwanda',
#  'Servicos e Tecnologia',
#  'Karratha',
#  'own prove',
#  'share license',
#  'de Strasbourg',
#  'kalkbult',
#  'high retardance',
#  'Distribucija Plina',
#  'virginia',
#  'locate Linz',
#  'Stockholm Sweden',
#  'Shanxi Northern Xingan',
#  'Bogota',
#  'france',
#  'paint resin',
#  'Empresas Lipigas',
#  'locate British',
#  'Casa de',
#  'Bergen Norway',
#  'start Houston',
#  'Rome project execution',
#  'ireland',
#  'locate Baierbrunn',
#  'Makati Philippines',
#  'deal Spain',
#  'bangalore',
#  'Comercializadora De Energia',
#  'green star royalties ltd',
#  'locate Milan',
#  'Parque das',
#  'plasma physics basis',
#  'shapoorji pallonji infrastructure capital co pvt ltd',
#  'Penta Capital',
#  'Enso Serraria Arapoti',
#  'undeveloped Kultuk',
#  'Khanty Mansiisk',
#  'Adelaide Australia',
#  'application name LUUP',
#  'southeastern Ohio',
#  'Brasil Energia',
#  'engage foreigner',
#  'locate Ibri',
#  'Virginia',
#  'New South Wales',
#  'include datum',
#  'Alberto Pasqualini SA',
#  'granada',
#  'locate India',
#  'Campos',
#  'locate Ewing',
#  'Haltenbanken area',
#  'Chicago',
#  'istrabenz',
#  'Germany Hungary',
#  'African Region',
#  'Cordoba Mendoza',
#  'northern new south wales',
#  'Paulo',
#  'locate Caarapo',
#  'Argentina include',
#  'the schiehallion field',
#  'Blue Raven',
#  'Jakarta Indonesia',
#  'Importadora de',
#  'Rio de Janeiro',
#  'Tengiz Korolev',
#  'foreigner recruitment business',
#  'export global',
#  'activity cover',
#  'Severo Danilovskoye',
#  'turkmenistan',
#  'locate Natal',
#  'Latina Distribuidora',
#  'Kansas Wyoming',
#  'asset include low',
#  'Nagaoka Karyoku Hatsudensho',
#  'Irwindale',
#  'Barcelona provide',
#  'jeito capital sas',
#  'new brunswick',
#  'Amadeus Southeast Asia',
#  'insurance include personal',
#  'de la Republique',
#  'Madre de Dios',
#  'Barcelona Spain',
#  'Macae Brazil',
#  'allnex holding',
#  'North Alexandria',
#  'locate Turin',
#  'baudroie-merou',
#  'bogota',
#  'Vida Cruz del',
#  'Teas Terminal Exportador',
#  'Petronet India',
#  'Suriname BV',
#  'Brazil',
#  'Germany own',
#  'ho chi minh city',
#  'Shell Pakistan Ltd',
#  'India Singapore',
#  'Smile Airways',
#  'La Rioja',
#  'public access charge',
#  'locate Passo',
#  'brazi',
#  'Ivanka Pri Dunaji',
#  'M Boundi Field',
#  'Proenergia Internacional',
#  'locate Surinam',
#  'Assam',
#  'locate Cergy',
#  'OAO Gazprom Neft',
#  'Vancouver',
#  'Sociedade de',
#  'Hispanica del',
#  'locate Val',
#  'Prex Participacoes Societarias',
#  'local loop',
#  'Fotech Group Ltd',
#  'Indiana own',
#  'locate Narrabri',
#  'Minnesota Wisconsin',
#  'medellin',
#  'independent professional',
#  'Tecverde Engenharia SA',
#  'Selangor Malaysia',
#  'methacrylic monomer',
#  'locate Merrillville',
#  'locate Taiwan',
#  'Namibia own',
#  'Detroit Michigan',
#  'locate Rochester',
#  'Wales Australia',
#  'cheltenham',
#  'Grenoble France',
#  'Prncipe Suriname',
#  'Krishna Godavari',
#  'Catarina Sao',
#  'Colombia provide',
#  'block YPF',
#  'Palmerston North',
#  'Korolev',
#  'Southeast Asia',
#  'Beninoise des',
#  'locate Clichy',
#  'Brazi Romania',
#  'Sihirgaz Ticaret ve',
#  'Paris France',
#  'Sao Paulo',
#  'locate Nakagami',
#  'Virginia Kentucky',
#  'Zeebrugge Belgium',
#  'Siam Mitsui',
#  'Fotech Group',
#  'grupo ibereolica renovables',
#  'Eagle Ford Acreage',
#  'Taas Yuryakh',
#  'El Salvador',
#  'San Food',
#  'Turkey',
#  'Cruz del Sur',
#  'assam-arakan',
#  'Strasbourg locate',
#  'manufacture videotape film',
#  'improve organ transplant',
#  'Northern Australia',
#  'Kencana',
#  'Arizona',
#  'Brasileiro Sa',
#  'locate Speyer',
#  'second Sudanese',
#  'Blu Smart',
#  'Ichthys',
#  'locate Cipolletti',
#  'wyoming',
#  'Temuco Puerto',
#  'locate Constanta',
#  'Midia Block',
#  'istanbul',
#  'papua new guinea',
#  'zierbena',
#  'Hedland Newman',
#  'Pasadena California',
#  'mgallery',
#  'Torzhokskiy zavod',
#  'link Sudan',
#  'prominent Paints Pty',
#  'Liege',
#  'Transmission Cables',
#  'locate Roquefort',
#  'Ormen Lange',
#  'adelaide, south australia',
#  'Participacoes Sociais',
#  'Torzhokskiy',
#  'Beijing',
#  'crosslinker',
#  'Gladstone',
#  'City Neuquen',
#  'locate Strasbourg',
#  'Vida Cruz',
#  'Du Gabon',
#  'tanzania',
#  'Ribeirao Preto',
#  'Gir Somnath district',
#  'locate Brotas',
#  'polyolefins',
#  'Cividino Di Castelli',
#  'South America',
#  'Preto',
#  'locate Pasadena',
#  'Michigan Ohio',
#  'Lucca Italy',
#  'XCharge Inc',
#  'Petronas Suriname',
#  'Bois Du Gabon',
#  'Terminal Holding',
#  'undisclosed Enhanced',
#  'Australia Asia',
#  'base Brisbane',
#  'north canton',
#  'Chi Minh City',
#  'forzando',
#  'permit locate',
#  'Basis HTS',
#  'locate Mandaluyong',
#  'treat blood cancer',
#  'castrol india ltd',
#  'locate Florence',
#  'locate Manchester',
#  'Cekomastik Kimya',
#  'canned seafood',
#  'Netherlands',
#  'purifies terephthalic',
#  'locate Tanzania',
#  'locate Brazi',
#  'Japan',
#  'locate Odense',
#  'Luxembourg',
#  'Norway own',
#  'Edvard Grieg',
#  'locate Durango',
#  'pill drop',
#  'Gladstone Brisbane',
#  'locate Quincy',
#  'nationally know',
#  'Petrobras Quimica',
#  'grand rapids',
#  'Nexen Inc',
#  'country Europe',
#  'locate Mealhada',
#  'Murmansk region',
#  'locate American',
#  'Northern New South',
#  'Hungary provide',
#  'de Energia',
#  'Cerveza Negra',
#  'Sequesterd',
#  'Samburgskoye Neponyatnoye',
#  'Lower Zakum Concession',
#  'Gardunha locate',
#  'include Good Morning',
#  'own Odyssey',
#  'south sudan',
#  'Brazil Peru',
#  'Yevrotek Yugra',
#  'Mitra Persada',
#  'Bizkaia Zierbena',
#  'Eastern United States',
#  'Compagnie Beninoise des',
#  'Antofagasta Vina',
#  'portugal',
#  'Massachusetts provide',
#  'Khanty',
#  'moncure',
#  'Latina Distribuidora de',
#  'maranon',
#  'Guinea',
#  'Westport Connecticut',
#  'resonance charge',
#  'Bayu Undan',
#  'locate Angola',
#  'Portugal Holdings BV',
#  'del Sur SA',
#  'enable client',
#  'locate Aberdeen',
#  'Bolivia own',
#  'Clearspans Inc',
#  'Fukuoka Shi',
#  'Pranhita',
#  'Yurtici Yurtdisi Tasimacilik',
#  'locate Liverpool',
#  'uruguay',
#  'locate Chiang',
#  'Iquique Antofagasta',
#  'Madison',
#  'east kalimantan',
#  'Alaska New',
#  'Oklahoma Tennessee',
#  'Australia',
#  'Cumbres Andinas',
#  'locate Fowler',
#  'Bypass PBL',
#  'locate Accra',
#  'de Produtos Ltda',
#  'Neftegazovaia kompaniia',
#  'locate Rotterdam',
#  'Enso Serraria',
#  'Araxa Brazil',
#  'own AGEL',
#  'de Distribuicao',
#  'Conceicao',
#  'locate Marseille',
#  'locate Japan',
#  'Undan Darwin',
#  'Caesar Tonga',
#  'Compagnie Des Bois',
#  'paint ink',
#  'oregon',
#  'develop genetic',
#  'usina Paraiso',
#  'respect silo',
#  'Belgium Luxembourg',
#  'Federation north',
#  'Shawish West',
#  'locate Hallein',
#  'Monoprix brand',
#  'locate Oslo',
#  'Puteaux France',
#  'include South',
#  'locate Oeiras',
#  'locate Athens',
#  'oao Torzhokskiy',
#  'Malt Beer',
#  'Sanayi locate',
#  'kyrgyzstan',
#  'Neuquen Mendoza',
#  'Elgin Franklin',
#  'locate Uruguay',
#  'Australia provide',
#  'resistant hyudraulic',
#  'product include Fibrex',
#  'locate Tananger',
#  'locate Germany',
#  'rival militia struggle',
#  'Budapest Hungary',
#  'locate London',
#  'new york',
#  'include TrueAC',
#  'Bersama',
#  'Idrocarbury Italia Srl',
#  'Block locate',
#  'north louisiana',
#  'Wyoming',
#  'Sofia Bulgaria',
#  'name Klikin',
#  'nieuwegein',
#  'Clayton Williams gather',
#  'include PBL',
#  'Africa provide',
#  'Belgium NV',
#  'Beringen Belgium',
#  'locate Pennsylvania',
#  'Texas own',
#  'Italia Srl',
#  'Madagascar',
#  'locate Melbourne',
#  'africa',
#  'Illinois Indiana',
#  'alumina Primary',
#  'Oklahoma Kansas',
#  'locate UK',
#  'Mersin Turkey',
#  'Gangwondo province',
#  'ituiutaba',
#  'Pasadena',
#  'locate Ukraine',
#  'the northern west australia',
#  'Tasfiyehanesi',
#  'Kentucky own',
#  'include Mui',
#  'Thessaloniki Thessaly',
#  'Jeito Capital',
#  'primarily Tennessee',
#  'locate Cleburne',
#  'Victorian Brown',
#  'del Carmen',
#  'Scotia',
#  'locate Poland',
#  'Azerbaijan',
#  'Cia de Seguros',
#  'Brisbane',
#  'Papua New Guinea',
#  'Athens Greece',
#  'Grand Rapids',
#  'Austria',
#  'Santiago Chile',
#  'Sofia',
#  'Trinidad Tobago',
#  'hsh holding',
#  'raffinaderij shell mersin nv',
#  'Delaware own',
#  'alcoholic malt beverage',
#  'vina del mar',
#  'Kalimantan Jembayan',
#  'Tunisia Ltd',
#  'pt federal karyatama',
#  'Gabon',
#  'alexandria',
#  'Tunisia Netherlands',
#  'british columbia',
#  'Brooklyn New',
#  'Pallonji Infrastructure Capital',
#  'gladstone',
#  'videotape film',
#  'mossi & ghisolfi spa',
#  'locate Pune',
#  'merrillville',
#  'Vietnam Thailand',
#  'Baku Azerbaijan',
#  'detroit',
#  'Petroquimica Uniao SA',
#  'Kenya Ltd',
#  'north africa',
#  'chuchupa & ballena',
#  'iquique',
#  'North New',
#  'Ofisi Gaz',
#  'Juan Argentina',
#  'et Fils',
#  'pt tepian indah sukses',
#  'Azure Dynamics',
#  'Hangzhou',
#  'locate Tupman',
#  'Nuon Belgium NV',
#  'Verkhneichersky Mogdinsky',
#  'region Russian',
#  'arthritis insomnia',
#  'locate Istanbul',
#  'Medellin Colombia',
#  'Irwindale California',
#  'Le Bourget',
#  'Brasiliano Distribuidora',
#  'prodn licensing',
#  'Villacoublay France',
#  'nominal',
#  ...}

# %% [markdown]
# # METHOD 5

# %%
import pandas as pd
import spacy
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer
import numpy as np
from tqdm import tqdm

# Load data
df_train = pd.read_excel("TrainingSet.xlsx")
df_capabilities = pd.read_excel("List of capabilities.xlsx")

# Load Spacy Model with NER
nlp = spacy.load('en_core_web_sm')

# Load a pre-trained Sentence Transformer model
model = SentenceTransformer('all-MiniLM-L6-v2')

def extract_phrases(text):
    doc = nlp(text)
    phrases = set()
    for ent in doc.ents:  # Focus on entities typically indicative of capabilities
        if ent.label_ in ['PRODUCT', 'ORG']:
            phrases.add(ent.text.lower())

    # Generate n-grams and filter non-capability words
    allowed_pos_types = {'NOUN', 'PROPN', 'ADJ'}
    n_grams = [" ".join([token.lemma_ for token in doc[i:i+3] if token.pos_ in allowed_pos_types and not token.is_stop]) for i in range(len(doc)-2)]
    n_grams.extend([" ".join([token.lemma_ for token in doc[i:i+2] if token.pos_ in allowed_pos_types and not token.is_stop]) for i in range(len(doc)-1)])
    phrases.update(filter(None, n_grams))  # Filter empty strings
    return list(phrases)

df_train['phrases'] = df_train['Target Business Description'].apply(extract_phrases)
df_capabilities['phrases'] = df_capabilities['Technologies/Skills'].astype(str).apply(extract_phrases)

flat_capabilities = [item for sublist in df_capabilities['phrases'] for item in sublist]
capability_embeddings = np.array([model.encode(phrase) for phrase in tqdm(flat_capabilities, desc='Encoding Capabilities') if phrase.strip()])

new_capabilities = set()
similarity_threshold = 0.3  # Lower threshold to be more selective

for phrases in tqdm(df_train['phrases'], desc='Comparing Phrases'):
    for phrase in phrases:
        if phrase.strip():
            phrase_emb = model.encode(phrase)
            sims = cosine_similarity([phrase_emb], capability_embeddings)
            if all(sim < similarity_threshold for sim in sims[0]):
                new_capabilities.add(phrase)

print("New capabilities to consider adding:", new_capabilities)
# Out:
# /Users/aaryanshah/Library/Python/3.9/lib/python/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Encoding Capabilities: 100%|██████████| 685/685 [00:09<00:00, 71.20it/s]
# Comparing Phrases: 100%|██████████| 2532/2532 [18:42<00:00,  2.26it/s]
# New capabilities to consider adding: {'Chipmunk', 'Kentucky New', 'Kentucky Mississippi', 'Midwestern United States', 'Holding Germany II', 'health education', 'Minnetonka', 'Offloading Florence', 'China National', 'Sur field', 'Cruz del', 'Dynachisso Thai', 'block Kosmos', 'XIX Neptun', 'Zierbena Bizkaia', 'Budapest', 'toreador hungary ltd', 'southern United States', 'treasury banking', 'West Australia', 'Cruz De La', 'Settimo Torinese', 'Nagaoka Karyoku', 'Doha Qatar', 'border Norway', 'Bagnolet France', 'Montney northeast', 'Romans France', 'Brazil Azerbaijan', 'Mendoza Argentina', 'Papua Indonesia', 'Associati Societa di', 'Block Romania', 'the fuerte sur', 'Holding BVBA', 'Seri Begawan', 'Midwest', 'des Mille', 'Ibereolica Renovables', 'Chernichny block', 'Uttar Pradesh', 'Toreador Hungary Ltd', 'Participacoes Sociais SA', 'portfolio Isemaren', 'Netherlands Norway', 'Aparecida Taboado', 'Vadodara Gujarat', 'Reading UK', 'burglary insurance', 'Anglo Siberian', 'Beringen', '12/3/257 east algoa', 'block 1', 'Tobago', 'place de la republique', 'sur Avre', 'Mime Distribuidora de', 'Frigorifico Fiordosur', 'mail Croatian', 'region Dobrogea', 'Biochemtex Beta', 'continent area', 'engraving metal', 'TotalEnergies EP Canada', 'Burnaby British', "Et D'Isolation SA", 'Chile SAC', 'Neuquen City Neuquen', 'View Illinois', 'Actividades de Construccion', 'Importadora', 'purpose vechicle', 'Empreendimentos e Participacoes', 'rapsodia&trident Blocks Licenses', 'China Australia', 'Colombia Peru', 'Cusiana Cupiagua', 'idrocarbury italia srl', 'Fibras SA', 'Pallonji Infrastructure', 'Greece', 'Concepcion Temuco', 'asset Apache', 'Horse Cerveza', 'Sur Fuerte', 'Shell Ghana Ltd', 'Cerveza', 'Thorntons Inc', 'Mereenie', 'export activity', 'Shetland Islands', 'Eolicas Riojanas', 'Equinor Brasil', 'Unity FPSO', 'Global Clearspans', 'Gazprom Neft', 'mereenie', 'Chennai India', 'Iputi Empreendimentos', 'Velizy Villacoublay', 'insurance burglary', 'South East Asia', 'Sequesterd Aggregate', 'Southeast Kalimantan', 'amoco mitsui', 'Utah Louisiana', 'Goias Brazil', 'Gerais', 'Bronberger Kessler', 'cover tire', 'Tasmania', 'Loire France', 'Jisike', 'Frigorifico Fiordosur SA', 'UK Norway', 'Sycamore formation', 'Thai PET', 'Mendoza San', 'multiple simultaneous event', 'Copenhagen Denmark', 'Calysta Inc', 'Clarence Moreton', 'Uganda', 'East Africa', 'Saraburi Lumlukka', 'decarbonize asset', 'German Products PCL', 'Ghisolfi', 'Az Zhara', 'Neponyatnoye', 'British Colombia', 'Neftyanaya Kompaniya Alyans', 'Food PCL', 'Acoreana Armazenagem de', 'North Canton', 'Thai Smile', 'parque das conchas', 'Enerco Enerji Sanayi', 'Oberhausen', 'Houma Louisiana', 'Bruderheim Alberta', 'Cruz Alta Participacoes', 'principal Creditos Hipotecarios', 'Sites Testing', 'Apache Canada Ltd', 'Nuevo Alisal', 'Petrobras de Valores', 'Yakhinskoye', 'turkey', 'Muturi', 'Luxembourg France', "Ste Generale D'Entretien", 'Clichy', 'Parque Eolico', 'tenement close', 'Shapoorji Pallonji Infrastructure', 'New Guinea', 'Petrobras Quimica SA', 'Etienne France', 'Bijgaarden', 'Buenos Aires', 'Uniboard USA', 'credit card fraud', 'Japan Brazil', 'Ibirite Brazil', 'Croda International', 'Tiszantuli Gazszolgaltato', 'major operator', 'Fundo Brazil', 'Cairo Egypt', 'Istrabenz Holdinska Druzba', 'de Ativos', 'SEI Servizi', 'Pei San Food', 'Nakagami', 'iliad', 'Gorgon Joint', 'P1929 P2304', 'Strasbourg France', 'Brisbane Australia', 'array', 'Marmara Depoculuk', 'Koninklijke Dsm Nv', 'North Carolina', 'Ticaret Sanayi', 'Timano Pechora', 'Shanxi', 'Energas SARL', 'Alicante Spain', 'Taino', 'asian American', 'Brazzaville', 'Mongstad Norway', 'Brazil Middle', 'Block B15', 'wine food', 'TMB Bank PCL', 'multi-activation jetting', 'decorative paint', 'Netherlands Germany', 'Videocon Mozambique', 'Sydney New', 'de Produtos', 'Vila Nova Conceicao', 'Open Sources', 'Tengiz', 'athabasca', 'metal closure', 'Kristiansund Norway', 'Northern Territory', 'Nenetsk Autonomous District', 'Adelaide South', 'Amoco Mitsu ...

# %% [markdown]
# # METHOD 6

# %%
import pandas as pd
import spacy
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer
import numpy as np
from tqdm import tqdm

# Load Spacy Model with technical terms awareness (if available)
nlp = spacy.load('en_core_web_sm')

# Load a pre-trained Sentence Transformer model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Custom function to filter out terms
def filter_terms(phrase_list):
    technical_terms = {'rigs', 'drilling', 'logging', 'simulation', 'seismic', 'surveys', 'management', 'engineering', 'production'}
    filtered = [phrase for phrase in phrase_list if any(term in phrase for term in technical_terms)]
    return filtered

# Function to extract phrases based on observed patterns in the capabilities list
def extract_phrases(text):
    doc = nlp(text)
    phrases = set()
    # Extract phrases based on part-of-speech tagging and named entities
    for chunk in doc.noun_chunks:
        if len(chunk.text.split()) <= 3:  # Limiting chunk length to filter out longer non-relevant phrases
            phrases.add(chunk.text.lower())

    # Filtering out non-technical terms
    phrases = filter_terms(list(phrases))
    return phrases

# Load data
df_train = pd.read_excel("TrainingSet.xlsx")
df_capabilities = pd.read_excel("List of capabilities.xlsx")

# Extract phrases from existing capabilities
df_capabilities['phrases'] = df_capabilities['Technologies/Skills'].astype(str).apply(extract_phrases)

# Flatten all capabilities into a single list and encode them
flat_capabilities = [item for sublist in df_capabilities['phrases'] for item in sublist]
capability_embeddings = np.array([model.encode(phrase) for phrase in tqdm(flat_capabilities, desc='Encoding Capabilities') if phrase.strip()])

# Process the training set descriptions
df_train['phrases'] = df_train['Target Business Description'].apply(extract_phrases)

# Identify new capabilities
new_capabilities = set()
similarity_threshold = 0.8  # Adjust based on sensitivity needs

for phrases in tqdm(df_train['phrases'], desc='Comparing Phrases'):
    for phrase in phrases:
        if phrase.strip():
            phrase_emb = model.encode(phrase)
            sims = cosine_similarity([phrase_emb], capability_embeddings)
            if all(sim < similarity_threshold for sim in sims[0]):
                new_capabilities.add(phrase)

print("New capabilities to consider adding:", new_capabilities)
# Out:
# /Users/aaryanshah/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/aaryanshah/Library/Python/3.9/lib/python/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# /Users/aaryanshah/Library/Python/3.9/lib/python/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Encoding Capabilities: 100%|██████████| 58/58 [00:01<00:00, 30.36it/s]
# Comparing Phrases: 100%|██████████| 2532/2532 [00:11<00:00, 211.08it/s]
# New capabilities to consider adding: {'power production', 'chlorine production facility', 'oil drilling equipment', 'well drilling services', 'petroleum production', '2017 forecast production', 'marine seismic data', 'facility management service', 'exploratory drilling', 'early production facilities', 'management', 'primary production', 'retail gasoline;petroleum production', '1994and first production', 'production licence pl093', 'productions', 'long-term management', 'production romania ltd', 'integrated petrochemical production', 'investment management services', 'production optimization', 'drilling programs', 'pipeline engineering company', 'retail petroleum production', 'a combined production', 'engineering services', 'construction management', 'increasing production', 'a daily production', 'electricity production facilities', 'the management', 'production engineering', 'bioengineering', 'order management', 'two production mines', 'genetic engineering software', 'engineering co ltd', 'demand management system', 'trade management solutions', 'oil drilling services', 'phillips production co', 'iliad drilling rig', '3-d seismic imaging', 'composite engineering inc', 'lower production costs', 'drilling equipment', 'production', 'the reproduction', 'petrovietnam drilling', 'kulluk drilling unit', 'advertising management platform', 'investment portfolio management', 'asset management provision', 'network management', 'house engineering', 'a production capacity', 'phillips drilling co.', 'gas production', 'production company', 'simulation', 'the production', 'production units', 'the sugar production', 'ieoc production bv', 'its onshore production', 'techman engineering ltd', 'oil production', 'engineering', 'the offshore production', 'shopping production centers', 'crop production services', 'environmental management', 'carbon engineering ltd', 'engineering tools', 'production site'}

# %%
len(new_capabilities)
# Out:
# 75

# %%
# save new capabilities to a excel file
df_new_capabilities = pd.DataFrame(list(new_capabilities), columns=['New Capabilities'])
df_new_capabilities.to_excel('/Users/aaryanshah/Oncampus-Job/NLP_Gal/iterations/iteration4.xlsx', index=False)
